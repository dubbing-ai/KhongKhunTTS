# %% [markdown]
# # Import

# %%
import string
import IPython
from IPython.display import Audio
import torch
import os
import random

from TTS.tts.utils.synthesis import synthesis
try:
  from TTS.utils.audio import AudioProcessor
except:
  from TTS.utils.audio import AudioProcessor
from TTS.tts.models import setup_model
from TTS.config import load_config
from TTS.tts.models.vits import *
from TTS.tts.utils.speakers import SpeakerManager

from TTS.bin.resample import resample_files
from TTS.utils.vad import get_vad_model_and_utils, remove_silence

# %% [markdown]
# # Define Parameter and Constant

# %%
OUT_PATH = 'output'
BASE_MODEL_PATH = './model'

# model vars 
MODEL_PATH = os.path.join(BASE_MODEL_PATH, 'best_model_160217.pth')
CONFIG_PATH = os.path.join(BASE_MODEL_PATH, 'config.json')
TTS_LANGUAGES = os.path.join(BASE_MODEL_PATH, 'language_ids.json')
USE_CUDA = torch.cuda.is_available()
SPEAKERS_FILE = os.path.join(BASE_MODEL_PATH, 'speakers.pth')
D_VECTOR_FILE = os.path.join(BASE_MODEL_PATH, 'dvector.pth')

model_name = MODEL_PATH.split(".")[0]

# %% [markdown]
# # Setup Model and Config

# %%
# load the config
C = load_config(CONFIG_PATH)

# load the audio processor
ap = AudioProcessor(**C.audio)

# override config
C["speakers_file"] = SPEAKERS_FILE
C["d_vector_file"] = D_VECTOR_FILE
C["language_ids_file"] = TTS_LANGUAGES

C["model_args"]["speakers_file"] = SPEAKERS_FILE
C["model_args"]["d_vector_file"] = D_VECTOR_FILE
C["model_args"]["language_ids_file"] = TTS_LANGUAGES

C["use_speaker_embedding"] = False
C["use_d_vector_file"] = True

C["model_args"]["use_speaker_embedding"] = False
C["model_args"]["use_d_vector_file"] = True

C.model_args['use_speaker_encoder_as_loss'] = False

model = setup_model(C)
cp = torch.load(MODEL_PATH, map_location=torch.device('cpu'))

model.load_state_dict(cp['model'])

model.eval()

if USE_CUDA:
  model = model.cuda()

# synthesize voice
use_griffin_lim = False
# Out:
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
#  > Using model: vits
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log10
#  | > min_level_db:0
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:None
#  | > fft_size:1024
#  | > power:None
#  | > preemphasis:0.0
#  | > griffin_lim_iters:None
#  | > signal_norm:None
#  | > symmetric_norm:None
#  | > mel_fmin:0
#  | > mel_fmax:None
#  | > pitch_fmin:None
#  | > pitch_fmax:None
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:10
#  | > hop_length:256
#  | > win_length:1024
# /Users/titor/Library/Caches/pypoetry/virtualenvs/khongkhuntts-EJcUAAU7-py3.11/lib/python3.11/site-packages/TTS/tts/utils/managers.py:20: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location="cpu")
# /Users/titor/Library/Caches/pypoetry/virtualenvs/khongkhuntts-EJcUAAU7-py3.11/lib/python3.11/site-packages/TTS/utils/io.py:51: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(f, map_location=map_location, **kwargs)
#  > Model fully restored.
#  > Setting up Audio Processor...
#  | > sample_rate:16000
#  | > resample:False
#  | > num_mels:64
#  | > log_func:np.log10
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:512
#  | > power:1.5
#  | > preemphasis:0.97
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:False
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:20.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:False
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:True
#  | > db_level:-27.0
#  | > stats_path:None
#  | > base:10
#  | > hop_length:160
#  | > win_length:400
#  > initialization of language-embedding layers.
# /var/folders/cm/lb23lq6s6f319w__2lgw1zfm0000gn/T/ipykernel_38662/2387045483.py:25: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   cp = torch.load(MODEL_PATH, map_location=torch.device('cpu'))

# %% [markdown]
# # Setup Language

# %%
# Select language
language_id = 0
language_name_to_id = model.language_manager.name_to_id
language_id_to_name = {v: k for k, v in language_name_to_id.items()}
print(f"Language ID: {language_id}, Language Name: {language_id_to_name[language_id]}")
# Out:
# Language ID: 0, Language Name: th

# %% [markdown]
# # Setup duration predictor

# %%
model.length_scale = 1.25  # scaler for the duration predictor. The larger it is, the slower the speech.
model.inference_noise_scale = 0.2 # defines the noise variance applied to the random z vector at inference.
model.inference_noise_scale_dp = 0.2 # defines the noise variance applied to the duration predictor z vector at inference.

# %% [markdown]
# # Setup speaker

# %%
speaker_id = 0
speaker_name_to_id =  model.speaker_manager.name_to_id
speaker_id_to_name = {v: k for k, v in speaker_name_to_id.items()}
speaker_name = speaker_id_to_name[speaker_id]
print(f"Speaker ID: {speaker_id}, Speaker Name: {speaker_name}")
# Out:
# Speaker ID: 0, Speaker Name: VCTK_cv001

# %% [markdown]
# # Inference

# %%
text = "และนี่คือธาตุทองซาว"
print(f" > text: {text} with sampling rate: {ap.sample_rate}")

wav, alignment, _, _ = synthesis(
                    model = model,
                    text = text,
                    CONFIG = C,
                    use_cuda = USE_CUDA,
                    # speaker_id = 0,
                    d_vector = model.speaker_manager.get_mean_embedding(speaker_name),
                    # style_wav = None,
                    language_id = language_id,
                    use_griffin_lim = True,
                    do_trim_silence = False,
                ).values()
print("Audio Generated")
IPython.display.display(Audio(wav, rate=ap.sample_rate))
# Out:
#  > text: และนี่คือธาตุทองซาว with sampling rate: 16000
# Audio Generated
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Save to Folder

# %%
file_name = text.replace(" ", "_")
file_name = model_name + '_' + file_name.translate(str.maketrans('', '', string.punctuation.replace('_', ''))) + '.wav'
out_path = os.path.join(OUT_PATH, speaker_name, file_name,)

print(f" > Saving output to {out_path}")

os.makedirs(f"{OUT_PATH}/{speaker_name}", exist_ok=True)
ap.save_wav(wav, out_path)
# Out:
#  > Saving output to output/VCTK_cv001/_และนี่คือธาตุทองซาว.wav

# %% [markdown]
# # Batch inference

# %%
# Setup speaker mapping
speaker_name_to_id = model.speaker_manager.name_to_id
speaker_id_to_name = {v: k for k, v in speaker_name_to_id.items()}
available_speaker_ids = list(speaker_id_to_name.keys())

# Create output directory
output_dir = "output_batch"
os.makedirs(output_dir, exist_ok=True)

# Read input texts
with open("input_texts.txt", 'r', encoding='utf-8') as f:
    texts = f.readlines()

# Open metadata file
with open(os.path.join(output_dir, "metadata.txt"), 'w', encoding='utf-8') as meta_file:
    # Process each text
    for text in texts:
        text = text.strip()
        if not text:  # Skip empty lines
            continue
            
        # Random speaker selection
        speaker_id = random.choice(available_speaker_ids)
        speaker_name = speaker_id_to_name[speaker_id]
        
        print(f"Processing: {text}")
        print(f"Selected speaker: {speaker_name} (ID: {speaker_id})")
        
        # Generate audio
        wav, alignment, _, _ = synthesis(
            model=model,
            text=text,
            CONFIG=C,
            use_cuda=USE_CUDA,
            d_vector=model.speaker_manager.get_mean_embedding(speaker_name),
            language_id=language_id,
            use_griffin_lim=True,
            do_trim_silence=False,
        ).values()
        
        # Save the audio file
        file_name = text.replace(" ", "_")
        file_name = "tts_" + file_name.translate(str.maketrans('', '', string.punctuation.replace('_', ''))) + '.wav'
        out_path = os.path.join(output_dir, file_name)
        
        print(f"Saving to: {out_path}")
        ap.save_wav(wav, out_path)
        
        # Write metadata
        meta_file.write(f"{file_name}|{speaker_name}\n")
        
        print("-" * 50)
# Out:
# Processing: ส่วนหน้าแข้งยาวเรียวและโค้งเหมาะที่จะใช้ในการจับเหยื่อ
# Selected speaker: VCTK_cv037 (ID: 36)
# Saving to: output_batch/tts_ส่วนหน้าแข้งยาวเรียวและโค้งเหมาะที่จะใช้ในการจับเหยื่อ.wav
# --------------------------------------------------
# Processing: ได้เลี้ยงตัวเหี้ยหรือตัวเงินตัวทองที่โผล่เข้ามาอยู่ในบ้าน
# Selected speaker: VCTK_cv092 (ID: 91)
# Saving to: output_batch/tts_ได้เลี้ยงตัวเหี้ยหรือตัวเงินตัวทองที่โผล่เข้ามาอยู่ในบ้าน.wav
# --------------------------------------------------
# Processing: ซึ่งจะมีเทคนิคแตกต่างกันทั้งการทำน้ำเคลือบและวิธีเคลือบทำให้ผลิตภัณฑ์สวยงามมีคุณค่า
# Selected speaker: VCTK_cv001 (ID: 0)
# Saving to: output_batch/tts_ซึ่งจะมีเทคนิคแตกต่างกันทั้งการทำน้ำเคลือบและวิธีเคลือบทำให้ผลิตภัณฑ์สวยงามมีคุณค่า.wav
# --------------------------------------------------
# Processing: เสียงพยัญชนะควบกล้ำในภาษาไทยมาตรฐานมีทั้งหมดสิบสองเสียงดังนี้
# Selected speaker: VCTK_cv006 (ID: 5)
# Saving to: output_batch/tts_เสียงพยัญชนะควบกล้ำในภาษาไทยมาตรฐานมีทั้งหมดสิบสองเสียงดังนี้.wav
# --------------------------------------------------
# Processing: แสตมป์ทองคำฉลองครองราชย์ชุดหมดแล้ว
# Selected speaker: VCTK_cv120 (ID: 119)
# Saving to: output_batch/tts_แสตมป์ทองคำฉลองครองราชย์ชุดหมดแล้ว.wav
# --------------------------------------------------
# Processing: ครั้นเงยหน้าขึ้นแล้วมองข้ามเตียงไปยังโต๊ะเครื่องแป้งอันมีกระจกเงาสูงแคบ
# Selected speaker: VCTK_cv110 (ID: 109)
# Saving to: output_batch/tts_ครั้นเงยหน้าขึ้นแล้วมองข้ามเตียงไปยังโต๊ะเครื่องแป้งอันมีกระจกเงาสูงแคบ.wav
# --------------------------------------------------
# Processing: โดยเฉพาะจากจีนเพราะหน่วยงานที่เกี่ยวข้องจะอ้างเรื่องความสัมพันธ์
# Selected speaker: VCTK_cv026 (ID: 25)
# Saving to: output_batch/tts_โดยเฉพาะจากจีนเพราะหน่วยงานที่เกี่ยวข้องจะอ้างเรื่องความสัมพันธ์.wav
# --------------------------------------------------
# Processing: ลงมาชั้นล่างได้พิมพ์ลภัสก็เขี่ยกระเป๋าแอบไว้ด้านหนึ่งก่อนกวักมือเรียกเด็กยกกระเป๋าแถวนั้น
# Selected speaker: VCTK_cv005 (ID: 4)
# Saving to: output_batch/tts_ลงมาชั้นล่างได้พิมพ์ลภัสก็เขี่ยกระเป๋าแอบไว้ด้านหนึ่งก่อนกวักมือเรียกเด็กยกกระเป๋าแถวนั้น.wav
# --------------------------------------------------
# Processing: สถานที่ทำบุญเลี้ยงพระไม่ได้จัดขึ้นที่อาคารแปดเหลี่ยมอย่างที่ใครใครนึก
# Selected speaker: VCTK_cv111 (ID: 110)
# Saving to: output_batch/tts_สถานที่ทำบุญเลี้ยงพระไม่ได้จัดขึ้นที่อาคารแปดเหลี่ยมอย่างที่ใครใครนึก.wav
# --------------------------------------------------
# Processing: สำหรับสาเหตุ
# Selected speaker: VCTK_cv090 (ID: 89)
# Saving to: output_batch/tts_สำหรับสาเหตุ.wav
# --------------------------------------------------
# Processing: เขารับคำด้วยสุ้มเสียงแจ่มใสทั้งทั้งที่สีหน้ามีเค้าเหนื่อยหน่ายเป็นที่ยิ่ง
# Selected speaker: VCTK_cv124 (ID: 123)
# Saving to: output_batch/tts_เขารับคำด้วยสุ้มเสียงแจ่มใสทั้งทั้งที่สีหน้ามีเค้าเหนื่อยหน่ายเป็นที่ยิ่ง.wav
# --------------------------------------------------
# Processing: เช่นเดียวกับสรรพคุณและวิธีใช้ของมะแว้งเครือ
# Selected speaker: VCTK_cv048 (ID: 47)
# Saving to: output_batch/tts_เช่นเดียวกับสรรพคุณและวิธีใช้ของมะแว้งเครือ.wav
# --------------------------------------------------
# Processing: และในรุ่นผมก็น้าวาดนี่แหละที่นับได้ว่าเป็นคนสุดท้ายของทางฝ่ายเมืองพิจิตรที่มาทางนี้
# Selected speaker: VCTK_cv040 (ID: 39)
# Saving to: output_batch/tts_และในรุ่นผมก็น้าวาดนี่แหละที่นับได้ว่าเป็นคนสุดท้ายของทางฝ่ายเมืองพิจิตรที่มาทางนี้.wav
# --------------------------------------------------
# Processing: พวกนี้จึงมีขั้นตอนการเจริญเติบโตสี่ระยะคือระยะไข่ตัวหนอนดักแด้และตัวเต็มวัย
# Selected speaker: VCTK_cv045 (ID: 44)
# Saving to: output_batch/tts_พวกนี้จึงมีขั้นตอนการเจริญเติบโตสี่ระยะคือระยะไข่ตัวหนอนดักแด้และตัวเต็มวัย.wav
# --------------------------------------------------
# Processing: ล้อมกรอบด้วยผมสลวยระบ่าสีน้ำตาลเข้มนัยน์ตาแกมเขียวเปล่งประกายมาดมั่น
# Selected speaker: VCTK_cv066 (ID: 65)
# Saving to: output_batch/tts_ล้อมกรอบด้วยผมสลวยระบ่าสีน้ำตาลเข้มนัยน์ตาแกมเขียวเปล่งประกายมาดมั่น.wav
# --------------------------------------------------
# Processing: จะทำหน้าที่หลักในการกรองอาหารจากน้ำและส่งเข้าปากในเพรียงหินที่โตเต็มวัย
# Selected speaker: VCTK_cv090 (ID: 89)
# Saving to: output_batch/tts_จะทำหน้าที่หลักในการกรองอาหารจากน้ำและส่งเข้าปากในเพรียงหินที่โตเต็มวัย.wav
# --------------------------------------------------
# Processing: พวกนั้นเอาข้าวลงไปคลุกในกระปุกน้ำพริกเลยนะฮะเด็ดผักตามริมทางริมทุ่งโอ้ยแซ่บหลายอย่าบอกใครเชียว
# Selected speaker: VCTK_cv111 (ID: 110)
# Saving to: output_batch/tts_พวกนั้นเอาข้าวลงไปคลุกในกระปุกน้ำพริกเลยนะฮะเด็ดผักตามริมทางริมทุ่งโอ้ยแซ่บหลายอย่าบอกใครเชียว.wav
# --------------------------------------------------
# Processing: ส่วนเครื่องตกแต่งองค์พระที่นั่งก็เป็นแบบจีนล้วนงดงามยิ่งยากที่จะหาที่เปรียบได้
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_ส่วนเครื่องตกแต่งองค์พระที่นั่งก็เป็นแบบจีนล้วนงดงามยิ่งยากที่จะหาที่เปรียบได้.wav
# --------------------------------------------------
# Processing: รายสุดท้ายพ่อค้ายาบ้าหนีตำรวจคุมตัวค้นห้องพลัดตกตึกหอพักสี่ชั้นย่านลาดกระบังดับ
# Selected speaker: VCTK_cv031 (ID: 30)
# Saving to: output_batch/tts_รายสุดท้ายพ่อค้ายาบ้าหนีตำรวจคุมตัวค้นห้องพลัดตกตึกหอพักสี่ชั้นย่านลาดกระบังดับ.wav
# --------------------------------------------------
# Processing: ยักษ์ใหญ่ไหวตัวฮัลโหลมือถือเดือดสุดสุด
# Selected speaker: VCTK_cv053 (ID: 52)
# Saving to: output_batch/tts_ยักษ์ใหญ่ไหวตัวฮัลโหลมือถือเดือดสุดสุด.wav
# --------------------------------------------------
# Processing: เลิกจีบพี่เถอะพี่ไม่ชอบเด็ก
# Selected speaker: VCTK_cv033 (ID: 32)
# Saving to: output_batch/tts_เลิกจีบพี่เถอะพี่ไม่ชอบเด็ก.wav
# --------------------------------------------------
# Processing: เนื่องจากอุณหภูมิสูงติดต่อกันหลายวัน
# Selected speaker: VCTK_cv090 (ID: 89)
# Saving to: output_batch/tts_เนื่องจากอุณหภูมิสูงติดต่อกันหลายวัน.wav
# --------------------------------------------------
# Processing: ชายหนุ่มรีบปล่อยหญิงสาวที่สวมเพียงชุดชั้นในตัวเดียว
# Selected speaker: VCTK_cv110 (ID: 109)
# Saving to: output_batch/tts_ชายหนุ่มรีบปล่อยหญิงสาวที่สวมเพียงชุดชั้นในตัวเดียว.wav
# --------------------------------------------------
# Processing: หญิงตั้งครรภ์ยังคงเดินทุบประตูไปเรื่อยเรื่อย
# Selected speaker: VCTK_cv047 (ID: 46)
# Saving to: output_batch/tts_หญิงตั้งครรภ์ยังคงเดินทุบประตูไปเรื่อยเรื่อย.wav
# --------------------------------------------------
# Processing: แต่ตอนนี้เจ้าตัวเล็กวุ่นวายอยู่หน่อยหน่อย
# Selected speaker: VCTK_cv028 (ID: 27)
# Saving to: output_batch/tts_แต่ตอนนี้เจ้าตัวเล็กวุ่นวายอยู่หน่อยหน่อย.wav
# --------------------------------------------------
# Processing: หัวหน้ากิ่งอำเภอโคกสูงตรวจสอบพบว่านายนูแสงแก้วเกิดเมื่อวันที่สี่เดือนหกปีเถาะ
# Selected speaker: VCTK_cv059 (ID: 58)
# Saving to: output_batch/tts_หัวหน้ากิ่งอำเภอโคกสูงตรวจสอบพบว่านายนูแสงแก้วเกิดเมื่อวันที่สี่เดือนหกปีเถาะ.wav
# --------------------------------------------------
# Processing: ได้แต่เงยหน้าหันไปตามเสียงด้วยความสงสัย
# Selected speaker: VCTK_cv045 (ID: 44)
# Saving to: output_batch/tts_ได้แต่เงยหน้าหันไปตามเสียงด้วยความสงสัย.wav
# --------------------------------------------------
# Processing: ใช้แรงอยู่ชั่วครู่นางจึงดันร่างนั้นให้พลิกหงายได้
# Selected speaker: VCTK_cv014 (ID: 13)
# Saving to: output_batch/tts_ใช้แรงอยู่ชั่วครู่นางจึงดันร่างนั้นให้พลิกหงายได้.wav
# --------------------------------------------------
# Processing: ผมจึงรับผิดชอบมาเยี่ยมพี่
# Selected speaker: VCTK_cv061 (ID: 60)
# Saving to: output_batch/tts_ผมจึงรับผิดชอบมาเยี่ยมพี่.wav
# --------------------------------------------------
# Processing: หากแต่เขามิได้มองเล่าก็เปล่าประโยชน์อันใด
# Selected speaker: VCTK_cv009 (ID: 8)
# Saving to: output_batch/tts_หากแต่เขามิได้มองเล่าก็เปล่าประโยชน์อันใด.wav
# --------------------------------------------------
# Processing: และนางเองก็ยังไม่พร้อมที่จะเข้าหอกับเขา
# Selected speaker: VCTK_cv065 (ID: 64)
# Saving to: output_batch/tts_และนางเองก็ยังไม่พร้อมที่จะเข้าหอกับเขา.wav
# --------------------------------------------------
# Processing: สิ่งที่ฉันต้องการก็แค่คะแนนที่พวกเราจะได้หลังจากเคลียร์เกมนี้ได้ต่างหาก
# Selected speaker: VCTK_cv104 (ID: 103)
# Saving to: output_batch/tts_สิ่งที่ฉันต้องการก็แค่คะแนนที่พวกเราจะได้หลังจากเคลียร์เกมนี้ได้ต่างหาก.wav
# --------------------------------------------------
# Processing: โชคดีแค่ไหนแล้วที่อีกฝ่ายไม่ฆ่าเขาทิ้งไปซะเดี๋ยวนี้เลย
# Selected speaker: VCTK_cv126 (ID: 125)
# Saving to: output_batch/tts_โชคดีแค่ไหนแล้วที่อีกฝ่ายไม่ฆ่าเขาทิ้งไปซะเดี๋ยวนี้เลย.wav
# --------------------------------------------------
# Processing: จังหวัดชายแดนภาคใต้เป็นตัวแทนผู้นำศาสนาอิสลามได้มอบเรือกอแระจำลอง
# Selected speaker: VCTK_cv120 (ID: 119)
# Saving to: output_batch/tts_จังหวัดชายแดนภาคใต้เป็นตัวแทนผู้นำศาสนาอิสลามได้มอบเรือกอแระจำลอง.wav
# --------------------------------------------------
# Processing: เมืองเลยต้องขยายเป็นแนวดิ่ง
# Selected speaker: VCTK_cv026 (ID: 25)
# Saving to: output_batch/tts_เมืองเลยต้องขยายเป็นแนวดิ่ง.wav
# --------------------------------------------------
# Processing: ปราณหิมะรูปแบบที่หิมะร่วงโรย
# Selected speaker: VCTK_cv002 (ID: 1)
# Saving to: output_batch/tts_ปราณหิมะรูปแบบที่หิมะร่วงโรย.wav
# --------------------------------------------------
# Processing: ส่วนอธิษฐ์รีบเบือนหน้าหลบพร้อมทำท่าจะขยับตัวลุกขึ้น
# Selected speaker: VCTK_cv091 (ID: 90)
# Saving to: output_batch/tts_ส่วนอธิษฐ์รีบเบือนหน้าหลบพร้อมทำท่าจะขยับตัวลุกขึ้น.wav
# --------------------------------------------------
# Processing: ริมฝีปากหนาจึงจู่โจมฉับพลันพร้อมกับหัวใจที่กำลังบีบรัด
# Selected speaker: VCTK_cv029 (ID: 28)
# Saving to: output_batch/tts_ริมฝีปากหนาจึงจู่โจมฉับพลันพร้อมกับหัวใจที่กำลังบีบรัด.wav
# --------------------------------------------------
# Processing: เคไว้เจอกันที่นั่นนะไปล่ะจังหวะนั้นที่เต้ยจะหันหลังไป
# Selected speaker: VCTK_cv097 (ID: 96)
# Saving to: output_batch/tts_เคไว้เจอกันที่นั่นนะไปล่ะจังหวะนั้นที่เต้ยจะหันหลังไป.wav
# --------------------------------------------------
# Processing: นิยายแปลเทพกระบี่มรณะตอนที่เจี้ยนเฉิน
# Selected speaker: VCTK_cv040 (ID: 39)
# Saving to: output_batch/tts_นิยายแปลเทพกระบี่มรณะตอนที่เจี้ยนเฉิน.wav
# --------------------------------------------------
# Processing: ทำให้นายผดุงแสดงอาการฉุนเฉียวพร้อมกับโวยวายว่าไหนมันอยู่ไหนเดี๋ยวจะตบปากมัน
# Selected speaker: VCTK_cv029 (ID: 28)
# Saving to: output_batch/tts_ทำให้นายผดุงแสดงอาการฉุนเฉียวพร้อมกับโวยวายว่าไหนมันอยู่ไหนเดี๋ยวจะตบปากมัน.wav
# --------------------------------------------------
# Processing: ไม่ถูกหลอกลวงหรือเอารัดเอาเปรียบพยายามควบคุมผลิตผลและควบคุมราคาของการซื้อขายให้ได้มาตรฐาน
# Selected speaker: VCTK_cv083 (ID: 82)
# Saving to: output_batch/tts_ไม่ถูกหลอกลวงหรือเอารัดเอาเปรียบพยายามควบคุมผลิตผลและควบคุมราคาของการซื้อขายให้ได้มาตรฐาน.wav
# --------------------------------------------------
# Processing: กลุ่มพันธมิตรประมาณสิบคนได้บุกเข้ามาในทำเนียบเลียบคลองผดุงกรุงเกษม
# Selected speaker: VCTK_cv054 (ID: 53)
# Saving to: output_batch/tts_กลุ่มพันธมิตรประมาณสิบคนได้บุกเข้ามาในทำเนียบเลียบคลองผดุงกรุงเกษม.wav
# --------------------------------------------------
# Processing: มลาวโซ่งหรือไทดำ
# Selected speaker: VCTK_cv055 (ID: 54)
# Saving to: output_batch/tts_มลาวโซ่งหรือไทดำ.wav
# --------------------------------------------------
# Processing: ซึ่งเมื่อเปรียบเทียบกับริ้วกระบวนเรือในสมัยเท่าที่พอจะรักษาไว้ได้เท่านั้น
# Selected speaker: VCTK_cv008 (ID: 7)
# Saving to: output_batch/tts_ซึ่งเมื่อเปรียบเทียบกับริ้วกระบวนเรือในสมัยเท่าที่พอจะรักษาไว้ได้เท่านั้น.wav
# --------------------------------------------------
# Processing: ทำให้วาริทต้องรีบเหลียวกลับมามองด้วยความประหลาดใจ
# Selected speaker: VCTK_cv090 (ID: 89)
# Saving to: output_batch/tts_ทำให้วาริทต้องรีบเหลียวกลับมามองด้วยความประหลาดใจ.wav
# --------------------------------------------------
# Processing: กลไกบางอย่างในดวงจิตทำให้มีเพียงภาพท้องฟ้าเวิ้งว้างและปุยเมฆสี
# Selected speaker: VCTK_cv096 (ID: 95)
# Saving to: output_batch/tts_กลไกบางอย่างในดวงจิตทำให้มีเพียงภาพท้องฟ้าเวิ้งว้างและปุยเมฆสี.wav
# --------------------------------------------------
# Processing: ฉันเกลียดนักเวลาเขายิ้มโกงโกงมีลับลมคมนัย
# Selected speaker: VCTK_cv054 (ID: 53)
# Saving to: output_batch/tts_ฉันเกลียดนักเวลาเขายิ้มโกงโกงมีลับลมคมนัย.wav
# --------------------------------------------------
# Processing: หญิงสาวขอบใจก่อนขับรถเข้าไปจอดด้านในประชาสัมพันธ์ช่วยบอกชั้น
# Selected speaker: VCTK_cv125 (ID: 124)
# Saving to: output_batch/tts_หญิงสาวขอบใจก่อนขับรถเข้าไปจอดด้านในประชาสัมพันธ์ช่วยบอกชั้น.wav
# --------------------------------------------------
# Processing: เพราะคุณเจ๊เธอขอเลี้ยงเพื่อนฝูงแทนการเลี้ยงเด็ก
# Selected speaker: VCTK_cv125 (ID: 124)
# Saving to: output_batch/tts_เพราะคุณเจ๊เธอขอเลี้ยงเพื่อนฝูงแทนการเลี้ยงเด็ก.wav
# --------------------------------------------------
# Processing: พระอาจารย์สิงห์ทองธัมมธโรพระอาจารย์สมชายฐิตวิริโยลที่อยู่จำพรรษากับท่าน
# Selected speaker: VCTK_cv122 (ID: 121)
# Saving to: output_batch/tts_พระอาจารย์สิงห์ทองธัมมธโรพระอาจารย์สมชายฐิตวิริโยลที่อยู่จำพรรษากับท่าน.wav
# --------------------------------------------------
# Processing: ต่อให้เราไม่กังขากับความน่าเชื่อถือของโพลชิ้นนี้ก็ยังคงมีคำถามที่น่าคิดอยู่ดี
# Selected speaker: VCTK_cv086 (ID: 85)
# Saving to: output_batch/tts_ต่อให้เราไม่กังขากับความน่าเชื่อถือของโพลชิ้นนี้ก็ยังคงมีคำถามที่น่าคิดอยู่ดี.wav
# --------------------------------------------------
# Processing: ยึดหลักโบราณราชประเพณีแต่เพียงอนุโลมซึ่งริ้วกระบวนเรือที่จอมพลสมเด็จพระเจ้าบรมวงศ์เธอเจ้าฟ้ากรมพระนครสวรรค์วรพินิตทูลเกล้าถวายมีดังนี้
# Selected speaker: VCTK_cv055 (ID: 54)
# Saving to: output_batch/tts_ยึดหลักโบราณราชประเพณีแต่เพียงอนุโลมซึ่งริ้วกระบวนเรือที่จอมพลสมเด็จพระเจ้าบรมวงศ์เธอเจ้าฟ้ากรมพระนครสวรรค์วรพินิตทูลเกล้าถวายมีดังนี้.wav
# --------------------------------------------------
# Processing: ดังปรากฏอยู่ในบทกาพย์ห่อโคลงเห่เรือของเจ้าฟ้าธรรมาธิเบศร์ว่าสุพรรณหงส์ทรงพู่ห้อยงามชดช้อยลอยหลังสินธุ์
# Selected speaker: VCTK_cv013 (ID: 12)
# Saving to: output_batch/tts_ดังปรากฏอยู่ในบทกาพย์ห่อโคลงเห่เรือของเจ้าฟ้าธรรมาธิเบศร์ว่าสุพรรณหงส์ทรงพู่ห้อยงามชดช้อยลอยหลังสินธุ์.wav
# --------------------------------------------------
# Processing: เครื่องบวงสรวงสะเดาะเคราะห์หรือทำขึ้นเพื่อรับเคราะห์แทนตนเช่นตุ๊กตาเสียกบาล
# Selected speaker: VCTK_cv057 (ID: 56)
# Saving to: output_batch/tts_เครื่องบวงสรวงสะเดาะเคราะห์หรือทำขึ้นเพื่อรับเคราะห์แทนตนเช่นตุ๊กตาเสียกบาล.wav
# --------------------------------------------------
# Processing: ย่างเตาแก๊สไม่ได้หรือ
# Selected speaker: VCTK_cv010 (ID: 9)
# Saving to: output_batch/tts_ย่างเตาแก๊สไม่ได้หรือ.wav
# --------------------------------------------------
# Processing: คราวนี้ผู้จัดการขยับแว่นส่ายหัวอย่างอ่อนใจ
# Selected speaker: VCTK_cv122 (ID: 121)
# Saving to: output_batch/tts_คราวนี้ผู้จัดการขยับแว่นส่ายหัวอย่างอ่อนใจ.wav
# --------------------------------------------------
# Processing: ไม่มีกลุ่มไม่มีขั้วทางการเมืองไม่ขึ้นกับกลุ่มใด
# Selected speaker: VCTK_cv076 (ID: 75)
# Saving to: output_batch/tts_ไม่มีกลุ่มไม่มีขั้วทางการเมืองไม่ขึ้นกับกลุ่มใด.wav
# --------------------------------------------------
# Processing: แม่ก็ยังห่วงของเหล่านั้น
# Selected speaker: VCTK_cv086 (ID: 85)
# Saving to: output_batch/tts_แม่ก็ยังห่วงของเหล่านั้น.wav
# --------------------------------------------------
# Processing: ชายหนุ่มนึกอยากเข้าไปจับตัวแม่คนร่างท้วมที่คลานต้วมเตี้ยมทำหน้าไม่รู้ไม่ชี้
# Selected speaker: VCTK_cv044 (ID: 43)
# Saving to: output_batch/tts_ชายหนุ่มนึกอยากเข้าไปจับตัวแม่คนร่างท้วมที่คลานต้วมเตี้ยมทำหน้าไม่รู้ไม่ชี้.wav
# --------------------------------------------------
# Processing: สมุดเล่มกระจ้อยร่อยเก่าและช้ำมาก
# Selected speaker: VCTK_cv015 (ID: 14)
# Saving to: output_batch/tts_สมุดเล่มกระจ้อยร่อยเก่าและช้ำมาก.wav
# --------------------------------------------------
# Processing: ตรงกับวันสิ้นเดือนสิบนับว่าเป็นวันนักขัตฤกษ์ที่คนไทยเรานิยมทำกันมาก
# Selected speaker: VCTK_cv087 (ID: 86)
# Saving to: output_batch/tts_ตรงกับวันสิ้นเดือนสิบนับว่าเป็นวันนักขัตฤกษ์ที่คนไทยเรานิยมทำกันมาก.wav
# --------------------------------------------------
# Processing: ก็คงจะมีเวลาไปตีกอล์ฟยิ่งช่วงนี้ยิ่งมือขึ้นอยู่
# Selected speaker: VCTK_cv091 (ID: 90)
# Saving to: output_batch/tts_ก็คงจะมีเวลาไปตีกอล์ฟยิ่งช่วงนี้ยิ่งมือขึ้นอยู่.wav
# --------------------------------------------------
# Processing: อคิราภ์พยักหน้าแต่พอลุกแข้งขาหล่อนก็ไร้เรี่ยวแรงกะทันหันมึนวูบจนหวิดจะล้มคว่ำลงดี
# Selected speaker: VCTK_cv039 (ID: 38)
# Saving to: output_batch/tts_อคิราภ์พยักหน้าแต่พอลุกแข้งขาหล่อนก็ไร้เรี่ยวแรงกะทันหันมึนวูบจนหวิดจะล้มคว่ำลงดี.wav
# --------------------------------------------------
# Processing: อนึ่งเสื้อสนอบพระราชทานนั้นแลเอาไปนุ่งห่มแห่งอื่นด้วยประการอันมิชอบนุ่งห่มให้เศร้าหมอง
# Selected speaker: VCTK_cv047 (ID: 46)
# Saving to: output_batch/tts_อนึ่งเสื้อสนอบพระราชทานนั้นแลเอาไปนุ่งห่มแห่งอื่นด้วยประการอันมิชอบนุ่งห่มให้เศร้าหมอง.wav
# --------------------------------------------------
# Processing: ท่านเลือกมาจำพรรษาอยู่ที่หมู่บ้านแห่งนี้เพราะเป็นพื้นที่ที่มีความสงบห่างไกลฝูงชนอันพลุกพล่าน
# Selected speaker: VCTK_cv048 (ID: 47)
# Saving to: output_batch/tts_ท่านเลือกมาจำพรรษาอยู่ที่หมู่บ้านแห่งนี้เพราะเป็นพื้นที่ที่มีความสงบห่างไกลฝูงชนอันพลุกพล่าน.wav
# --------------------------------------------------
# Processing: ความจริงเหมือนธารไม่อยากทำงานนี้หรอกแต่สถานการณ์บังคับให้ไม่มีทางเลือกงานใกล้โรงพยาบาล
# Selected speaker: VCTK_cv008 (ID: 7)
# Saving to: output_batch/tts_ความจริงเหมือนธารไม่อยากทำงานนี้หรอกแต่สถานการณ์บังคับให้ไม่มีทางเลือกงานใกล้โรงพยาบาล.wav
# --------------------------------------------------
# Processing: เจ้าของร้านโคลงหัวไปมาอย่างสมเพช
# Selected speaker: VCTK_cv117 (ID: 116)
# Saving to: output_batch/tts_เจ้าของร้านโคลงหัวไปมาอย่างสมเพช.wav
# --------------------------------------------------
# Processing: สามารถมีหลักประกันได้ว่าจะมีพระโอรสแน่แต่สมเด็จพระจักรพรรดิฮิโรฮิโตะพระราชบิดาของสมเด็จพระจักรพรรดิองค์ปัจจุบันได้ยกเลิกธรรมเนียมการมีสนมหลายคน
# Selected speaker: VCTK_cv046 (ID: 45)
# Saving to: output_batch/tts_สามารถมีหลักประกันได้ว่าจะมีพระโอรสแน่แต่สมเด็จพระจักรพรรดิฮิโรฮิโตะพระราชบิดาของสมเด็จพระจักรพรรดิองค์ปัจจุบันได้ยกเลิกธรรมเนียมการมีสนมหลายคน.wav
# --------------------------------------------------
# Processing: คุมโจ๋มั่วเซ็กซ์วันแห่งความรัก
# Selected speaker: VCTK_cv016 (ID: 15)
# Saving to: output_batch/tts_คุมโจ๋มั่วเซ็กซ์วันแห่งความรัก.wav
# --------------------------------------------------
# Processing: ครั้นพอแสร้งว่าหายไปจากเซฟก็เป็นไปไม่ได้อีก
# Selected speaker: VCTK_cv027 (ID: 26)
# Saving to: output_batch/tts_ครั้นพอแสร้งว่าหายไปจากเซฟก็เป็นไปไม่ได้อีก.wav
# --------------------------------------------------
# Processing: เสียงฝีเท้าทหารกระทบพื้นวนกลับมาพร้อมด้วยเสียงเพลงมาร์ชเป็นจังหวะ
# Selected speaker: VCTK_cv034 (ID: 33)
# Saving to: output_batch/tts_เสียงฝีเท้าทหารกระทบพื้นวนกลับมาพร้อมด้วยเสียงเพลงมาร์ชเป็นจังหวะ.wav
# --------------------------------------------------
# Processing: โขนเป็นการแสดงที่ใช้ท่ารำตามแบบละครใน
# Selected speaker: VCTK_cv070 (ID: 69)
# Saving to: output_batch/tts_โขนเป็นการแสดงที่ใช้ท่ารำตามแบบละครใน.wav
# --------------------------------------------------
# Processing: ในสมัยราคาถูกได้ยักย้ายเปลี่ยนแปลงขายทางโน้นซื้อทางนี้บางครั้งลงทุนซื้อที่ปลูกบ้าน
# Selected speaker: VCTK_cv003 (ID: 2)
# Saving to: output_batch/tts_ในสมัยราคาถูกได้ยักย้ายเปลี่ยนแปลงขายทางโน้นซื้อทางนี้บางครั้งลงทุนซื้อที่ปลูกบ้าน.wav
# --------------------------------------------------
# Processing: เขตเลือกตั้งที่สี่และห้ามมหาสารคามเขตเลือกตั้งที่สามแพร่
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_เขตเลือกตั้งที่สี่และห้ามมหาสารคามเขตเลือกตั้งที่สามแพร่.wav
# --------------------------------------------------
# Processing: เธอลูบไล้ศีรษะของลูกน้อยทาบมือปิดเปือกตาที่ยังคงลืมสว่างนั้น
# Selected speaker: VCTK_cv122 (ID: 121)
# Saving to: output_batch/tts_เธอลูบไล้ศีรษะของลูกน้อยทาบมือปิดเปือกตาที่ยังคงลืมสว่างนั้น.wav
# --------------------------------------------------
# Processing: ในทำนองเดียวกันหากไม่มีวัวควายไถนาหรือวัวควายผอมโซ
# Selected speaker: VCTK_cv063 (ID: 62)
# Saving to: output_batch/tts_ในทำนองเดียวกันหากไม่มีวัวควายไถนาหรือวัวควายผอมโซ.wav
# --------------------------------------------------
# Processing: ร่วมกับผู้เชี่ยวชาญด้านวัตถุระเบิดวางแนวทางการสืบสวนสอบสวนคลี่คลายคดี
# Selected speaker: VCTK_cv117 (ID: 116)
# Saving to: output_batch/tts_ร่วมกับผู้เชี่ยวชาญด้านวัตถุระเบิดวางแนวทางการสืบสวนสอบสวนคลี่คลายคดี.wav
# --------------------------------------------------
# Processing: ก็ยังดีกว่าคนหนีเมียวะนายมันไม่มีฝีมือมีเมียกี่คนต้องโดดหนีเขาหมด
# Selected speaker: VCTK_cv117 (ID: 116)
# Saving to: output_batch/tts_ก็ยังดีกว่าคนหนีเมียวะนายมันไม่มีฝีมือมีเมียกี่คนต้องโดดหนีเขาหมด.wav
# --------------------------------------------------
# Processing: เกิดจากการผุกร่อนของหินเนื้อดินละเอียดสีเนื้อ
# Selected speaker: VCTK_cv090 (ID: 89)
# Saving to: output_batch/tts_เกิดจากการผุกร่อนของหินเนื้อดินละเอียดสีเนื้อ.wav
# --------------------------------------------------
# Processing: พวกเขาถึงกับเกลียดตัวเองที่ยอมยืมเงินเพื่อมาเพื่อซื้ออุปกรณ์ชิ้นนี้
# Selected speaker: VCTK_cv133 (ID: 132)
# Saving to: output_batch/tts_พวกเขาถึงกับเกลียดตัวเองที่ยอมยืมเงินเพื่อมาเพื่อซื้ออุปกรณ์ชิ้นนี้.wav
# --------------------------------------------------
# Processing: เหรียญทองแดงต่อถ้วยเท่านั้น
# Selected speaker: VCTK_cv007 (ID: 6)
# Saving to: output_batch/tts_เหรียญทองแดงต่อถ้วยเท่านั้น.wav
# --------------------------------------------------
# Processing: เธอไม่มีทางเชื่อว่าฉีเฟิงจะจริงใจกับเธอแม้ว่าเธอจะถูกตีจนตายก็ตาม
# Selected speaker: VCTK_cv015 (ID: 14)
# Saving to: output_batch/tts_เธอไม่มีทางเชื่อว่าฉีเฟิงจะจริงใจกับเธอแม้ว่าเธอจะถูกตีจนตายก็ตาม.wav
# --------------------------------------------------
# Processing: ปีเขาเข้าใจกฏของเกมอย่างถ่องแท้
# Selected speaker: VCTK_cv034 (ID: 33)
# Saving to: output_batch/tts_ปีเขาเข้าใจกฏของเกมอย่างถ่องแท้.wav
# --------------------------------------------------
# Processing: โรคนี้เกิดจากฐานสมองได้รับการติดเชื้อการขาดวิตามินประเภทโฟรลิคแอซิดเส้นเลือดสมองตีบตัน
# Selected speaker: VCTK_cv104 (ID: 103)
# Saving to: output_batch/tts_โรคนี้เกิดจากฐานสมองได้รับการติดเชื้อการขาดวิตามินประเภทโฟรลิคแอซิดเส้นเลือดสมองตีบตัน.wav
# --------------------------------------------------
# Processing: ขวานที่บินมาด้วยความเร็วสูงกำลังจะพุ่งใส่ฉีเฟิงแล้ว
# Selected speaker: VCTK_cv130 (ID: 129)
# Saving to: output_batch/tts_ขวานที่บินมาด้วยความเร็วสูงกำลังจะพุ่งใส่ฉีเฟิงแล้ว.wav
# --------------------------------------------------
# Processing: หีบสมบัติระดับทองแดง
# Selected speaker: VCTK_cv076 (ID: 75)
# Saving to: output_batch/tts_หีบสมบัติระดับทองแดง.wav
# --------------------------------------------------
# Processing: ฉีเฟิงมองไปที่การแจ้งเตือนเห็นว่ามันเป็นเสียงปลุกที่เขาได้ตั้งไว้ก่อนหน้านี้
# Selected speaker: VCTK_cv041 (ID: 40)
# Saving to: output_batch/tts_ฉีเฟิงมองไปที่การแจ้งเตือนเห็นว่ามันเป็นเสียงปลุกที่เขาได้ตั้งไว้ก่อนหน้านี้.wav
# --------------------------------------------------
# Processing: หากเปรียบเทียบกับก่อนหน้านี้แล้วความแข็งแกร่งของเธอในตอนนี้ได้เพิ่มขึ้นอย่างมาก
# Selected speaker: VCTK_cv063 (ID: 62)
# Saving to: output_batch/tts_หากเปรียบเทียบกับก่อนหน้านี้แล้วความแข็งแกร่งของเธอในตอนนี้ได้เพิ่มขึ้นอย่างมาก.wav
# --------------------------------------------------
# Processing: ได้ทราบชื่อนักท่องเที่ยวเคราะห์ร้ายภายหลังคือนายคีทอัมเตอร์ดรัมอายุสี่สิบสองปี
# Selected speaker: VCTK_cv131 (ID: 130)
# Saving to: output_batch/tts_ได้ทราบชื่อนักท่องเที่ยวเคราะห์ร้ายภายหลังคือนายคีทอัมเตอร์ดรัมอายุสี่สิบสองปี.wav
# --------------------------------------------------
# Processing: นักผจญภัยเอ๋ยพิธีได้สิ้นสุดลงแล้ว
# Selected speaker: VCTK_cv068 (ID: 67)
# Saving to: output_batch/tts_นักผจญภัยเอ๋ยพิธีได้สิ้นสุดลงแล้ว.wav
# --------------------------------------------------
# Processing: เธอสามารถหลบกรงเล็บที่โจมตีจากข้างหลังของเธอได้
# Selected speaker: VCTK_cv094 (ID: 93)
# Saving to: output_batch/tts_เธอสามารถหลบกรงเล็บที่โจมตีจากข้างหลังของเธอได้.wav
# --------------------------------------------------
# Processing: โดยขอชดเชยค่าเสียเวลาให้เขาเครดิต
# Selected speaker: VCTK_cv070 (ID: 69)
# Saving to: output_batch/tts_โดยขอชดเชยค่าเสียเวลาให้เขาเครดิต.wav
# --------------------------------------------------
# Processing: เข้โผล่ขึ้นมาบริเวณร่องน้ำหลังโรงโม่แป้งมันโค้วชั่งเฮี๊ยะหมู่หนึ่ง
# Selected speaker: VCTK_cv047 (ID: 46)
# Saving to: output_batch/tts_เข้โผล่ขึ้นมาบริเวณร่องน้ำหลังโรงโม่แป้งมันโค้วชั่งเฮี๊ยะหมู่หนึ่ง.wav
# --------------------------------------------------
# Processing: ผ้าคลุมของผู้สืบสานแห่งความมืดระดับเงิน
# Selected speaker: VCTK_cv049 (ID: 48)
# Saving to: output_batch/tts_ผ้าคลุมของผู้สืบสานแห่งความมืดระดับเงิน.wav
# --------------------------------------------------
# Processing: ในความเป็นจริงแล้วฉีเฟิงไม่ได้อยากใช้ม้วนคัมภีร์ระดับ
# Selected speaker: VCTK_cv081 (ID: 80)
# Saving to: output_batch/tts_ในความเป็นจริงแล้วฉีเฟิงไม่ได้อยากใช้ม้วนคัมภีร์ระดับ.wav
# --------------------------------------------------
# Processing: มันคุ้มค่ามากเธอจะยอมจ่ายเหรียญเงินเพื่อซื้อมาสักอันหนึ่ง
# Selected speaker: VCTK_cv034 (ID: 33)
# Saving to: output_batch/tts_มันคุ้มค่ามากเธอจะยอมจ่ายเหรียญเงินเพื่อซื้อมาสักอันหนึ่ง.wav
# --------------------------------------------------
# Processing: เหยื่อกามแฉอุ๊เซียนบอล
# Selected speaker: VCTK_cv044 (ID: 43)
# Saving to: output_batch/tts_เหยื่อกามแฉอุ๊เซียนบอล.wav
# --------------------------------------------------
# Processing: ฉีเฟิงอยากจะหยิบเครื่องดื่มเย็นออกมาดื่มมาก
# Selected speaker: VCTK_cv097 (ID: 96)
# Saving to: output_batch/tts_ฉีเฟิงอยากจะหยิบเครื่องดื่มเย็นออกมาดื่มมาก.wav
# --------------------------------------------------
# Processing: ยิ่งไปกว่านั้นหากพวกเขาสามารถเคลียร์ดันเจี้ยนเป็นได้เป็นทีมแรก
# Selected speaker: VCTK_cv062 (ID: 61)
# Saving to: output_batch/tts_ยิ่งไปกว่านั้นหากพวกเขาสามารถเคลียร์ดันเจี้ยนเป็นได้เป็นทีมแรก.wav
# --------------------------------------------------
# Processing: เอาอะไรเพิ่มอีกมั๊ยครับลูก
# Selected speaker: VCTK_cv080 (ID: 79)
# Saving to: output_batch/tts_เอาอะไรเพิ่มอีกมั๊ยครับลูก.wav
# --------------------------------------------------
# Processing: ก็ฉันเอียนกับการทำเรื่องแบบนี้แล้วนี้นานายก็ด้วยไม่ใช่เหรอแซม
# Selected speaker: VCTK_cv071 (ID: 70)
# Saving to: output_batch/tts_ก็ฉันเอียนกับการทำเรื่องแบบนี้แล้วนี้นานายก็ด้วยไม่ใช่เหรอแซม.wav
# --------------------------------------------------
# Processing: คิดแล้วก็เครียด
# Selected speaker: VCTK_cv070 (ID: 69)
# Saving to: output_batch/tts_คิดแล้วก็เครียด.wav
# --------------------------------------------------
# Processing: เขาที่ไม่ได้กินข้าวมาตั้งแต่เมื่อวาน
# Selected speaker: VCTK_cv131 (ID: 130)
# Saving to: output_batch/tts_เขาที่ไม่ได้กินข้าวมาตั้งแต่เมื่อวาน.wav
# --------------------------------------------------
# Processing: คุณหมอมาดเปรี้ยวผู้คร่ำหวอดในงานนิติเวชกล่าวในฐานะแม่คนหนึ่ง
# Selected speaker: VCTK_cv048 (ID: 47)
# Saving to: output_batch/tts_คุณหมอมาดเปรี้ยวผู้คร่ำหวอดในงานนิติเวชกล่าวในฐานะแม่คนหนึ่ง.wav
# --------------------------------------------------
# Processing: ทุกวินาทีเหมือนจะปลิดชีพ
# Selected speaker: VCTK_cv062 (ID: 61)
# Saving to: output_batch/tts_ทุกวินาทีเหมือนจะปลิดชีพ.wav
# --------------------------------------------------
# Processing: คนาธิปเดินเข้าไปใกล้และเขี่ยปอยผมของคนป่วยบนเตียงเล่นอย่างจงใจ
# Selected speaker: VCTK_cv029 (ID: 28)
# Saving to: output_batch/tts_คนาธิปเดินเข้าไปใกล้และเขี่ยปอยผมของคนป่วยบนเตียงเล่นอย่างจงใจ.wav
# --------------------------------------------------
# Processing: และดวงตาของเขามีเสน่ห์อย่างมาก
# Selected speaker: VCTK_cv094 (ID: 93)
# Saving to: output_batch/tts_และดวงตาของเขามีเสน่ห์อย่างมาก.wav
# --------------------------------------------------
# Processing: ถึงจะได้อาบน้ำเตรียมตัวไปโรงเรียน
# Selected speaker: VCTK_cv133 (ID: 132)
# Saving to: output_batch/tts_ถึงจะได้อาบน้ำเตรียมตัวไปโรงเรียน.wav
# --------------------------------------------------
# Processing: แต่ได้เสียชีวิตด้วยโรคชราทำให้พวงครามเหลือตัวคนเดียว
# Selected speaker: VCTK_cv082 (ID: 81)
# Saving to: output_batch/tts_แต่ได้เสียชีวิตด้วยโรคชราทำให้พวงครามเหลือตัวคนเดียว.wav
# --------------------------------------------------
# Processing: หลังจากคลอดภูตะวันไม่นาน
# Selected speaker: VCTK_cv074 (ID: 73)
# Saving to: output_batch/tts_หลังจากคลอดภูตะวันไม่นาน.wav
# --------------------------------------------------
# Processing: เขากลับสร้างความเข้าใจผิดให้กับเธอเป็นวงกว้าง
# Selected speaker: VCTK_cv065 (ID: 64)
# Saving to: output_batch/tts_เขากลับสร้างความเข้าใจผิดให้กับเธอเป็นวงกว้าง.wav
# --------------------------------------------------
# Processing: เอาเถอะอย่างน้อยหัวใจกับไตของมันก็ยังขายได้
# Selected speaker: VCTK_cv045 (ID: 44)
# Saving to: output_batch/tts_เอาเถอะอย่างน้อยหัวใจกับไตของมันก็ยังขายได้.wav
# --------------------------------------------------
# Processing: ตั้งแต่ที่พ่อของเขาจากไปป้าก็มารับเขาไปดูแล
# Selected speaker: VCTK_cv108 (ID: 107)
# Saving to: output_batch/tts_ตั้งแต่ที่พ่อของเขาจากไปป้าก็มารับเขาไปดูแล.wav
# --------------------------------------------------
# Processing: พระราชกำหนดยกเว้นการจัดเก็บภาษีธุรกิจเฉพาะของการซื้อหรือขายตั๋วเงินหรือตราสารแสดงสิทธิ
# Selected speaker: VCTK_cv105 (ID: 104)
# Saving to: output_batch/tts_พระราชกำหนดยกเว้นการจัดเก็บภาษีธุรกิจเฉพาะของการซื้อหรือขายตั๋วเงินหรือตราสารแสดงสิทธิ.wav
# --------------------------------------------------
# Processing: วันนี้มีตรวจร่างกาย
# Selected speaker: VCTK_cv123 (ID: 122)
# Saving to: output_batch/tts_วันนี้มีตรวจร่างกาย.wav
# --------------------------------------------------
# Processing: เด็กชายหัวฟูสีฝางพูดขึ้นพร้อมกับตั้งท่าจะโจมตีใส่เด็กชายนามเดกุที่เจ้าตนเรียก
# Selected speaker: VCTK_cv103 (ID: 102)
# Saving to: output_batch/tts_เด็กชายหัวฟูสีฝางพูดขึ้นพร้อมกับตั้งท่าจะโจมตีใส่เด็กชายนามเดกุที่เจ้าตนเรียก.wav
# --------------------------------------------------
# Processing: ทั้งนี้ขอแจ้งว่าเราไม่มีทักษะการแปลอะไรทั้งนั้นนะฮะเราแปลจากอิ้ง
# Selected speaker: VCTK_cv123 (ID: 122)
# Saving to: output_batch/tts_ทั้งนี้ขอแจ้งว่าเราไม่มีทักษะการแปลอะไรทั้งนั้นนะฮะเราแปลจากอิ้ง.wav
# --------------------------------------------------
# Processing: เพ้อมากของเธอคนนั้นหรอ
# Selected speaker: VCTK_cv120 (ID: 119)
# Saving to: output_batch/tts_เพ้อมากของเธอคนนั้นหรอ.wav
# --------------------------------------------------
# Processing: หน้าเหมือนกระต่ายจังวะแกน่ะ
# Selected speaker: VCTK_cv001 (ID: 0)
# Saving to: output_batch/tts_หน้าเหมือนกระต่ายจังวะแกน่ะ.wav
# --------------------------------------------------
# Processing: ตั้งแต่พุทธศักราชสองพันห้าร้อยสิบเก้าเป็นต้นมา
# Selected speaker: VCTK_cv003 (ID: 2)
# Saving to: output_batch/tts_ตั้งแต่พุทธศักราชสองพันห้าร้อยสิบเก้าเป็นต้นมา.wav
# --------------------------------------------------
# Processing: โดยรายงานจากกรุงเคียฟเมืองหลวงของสาธารณรัฐยูเครนว่า
# Selected speaker: VCTK_cv012 (ID: 11)
# Saving to: output_batch/tts_โดยรายงานจากกรุงเคียฟเมืองหลวงของสาธารณรัฐยูเครนว่า.wav
# --------------------------------------------------
# Processing: เตี้ยบ่นต่อเจ้าหน้าที่ที่นั่งอยู่ที่โต๊ะว่ารอเหงือกแห้งแล้วยืดเยื้ออยู่ได้
# Selected speaker: VCTK_cv035 (ID: 34)
# Saving to: output_batch/tts_เตี้ยบ่นต่อเจ้าหน้าที่ที่นั่งอยู่ที่โต๊ะว่ารอเหงือกแห้งแล้วยืดเยื้ออยู่ได้.wav
# --------------------------------------------------
# Processing: และจำเลยทั้งสองก็ยังอยู่ในระหว่างเข้าสู่กระบวนการของศาลอุทธรณ์
# Selected speaker: VCTK_cv063 (ID: 62)
# Saving to: output_batch/tts_และจำเลยทั้งสองก็ยังอยู่ในระหว่างเข้าสู่กระบวนการของศาลอุทธรณ์.wav
# --------------------------------------------------
# Processing: ด้วยทรงรำลึกถึงผู้ยากไร้เจ็บป่วยและตกอยู่ในห้วงทุกข์อย่างสาหัสมากกว่า
# Selected speaker: VCTK_cv008 (ID: 7)
# Saving to: output_batch/tts_ด้วยทรงรำลึกถึงผู้ยากไร้เจ็บป่วยและตกอยู่ในห้วงทุกข์อย่างสาหัสมากกว่า.wav
# --------------------------------------------------
# Processing: ที่ยี่สิบแปดกุมภาพันธ์สองพันห้าร้อยห้าสิบ
# Selected speaker: VCTK_cv002 (ID: 1)
# Saving to: output_batch/tts_ที่ยี่สิบแปดกุมภาพันธ์สองพันห้าร้อยห้าสิบ.wav
# --------------------------------------------------
# Processing: เขาไม่ปฏิบัติตามกลับขับไปเรื่อยเรื่อย
# Selected speaker: VCTK_cv020 (ID: 19)
# Saving to: output_batch/tts_เขาไม่ปฏิบัติตามกลับขับไปเรื่อยเรื่อย.wav
# --------------------------------------------------
# Processing: หัวเหง้าเช่นขิงข่ากระชายรากผักชีหัวผักกาดหัวหอมหัวกระเทียมหัวสาคู
# Selected speaker: VCTK_cv091 (ID: 90)
# Saving to: output_batch/tts_หัวเหง้าเช่นขิงข่ากระชายรากผักชีหัวผักกาดหัวหอมหัวกระเทียมหัวสาคู.wav
# --------------------------------------------------
# Processing: ถามย้ำว่าการลงตัวดังกล่าวอาจมีคนมองว่ามีการเจรจาเรื่องโควตาลงตัว
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_ถามย้ำว่าการลงตัวดังกล่าวอาจมีคนมองว่ามีการเจรจาเรื่องโควตาลงตัว.wav
# --------------------------------------------------
# Processing: ซึ่งมีลักษณะในรายละเอียดดังนี้
# Selected speaker: VCTK_cv072 (ID: 71)
# Saving to: output_batch/tts_ซึ่งมีลักษณะในรายละเอียดดังนี้.wav
# --------------------------------------------------
# Processing: ได้ทอดพระเนตรเห็นอาคารสมัยใหม่หลังหนึ่งสร้างขึ้นบนที่ซึ่งเคยเป็นซากโบราณสถานมีพระราชดำรัสว่า
# Selected speaker: VCTK_cv065 (ID: 64)
# Saving to: output_batch/tts_ได้ทอดพระเนตรเห็นอาคารสมัยใหม่หลังหนึ่งสร้างขึ้นบนที่ซึ่งเคยเป็นซากโบราณสถานมีพระราชดำรัสว่า.wav
# --------------------------------------------------
# Processing: ในสมัยนั้นพื้นที่ตรงนี้ยังไม่เจริญแต่ขณะนี้ถือว่า
# Selected speaker: VCTK_cv020 (ID: 19)
# Saving to: output_batch/tts_ในสมัยนั้นพื้นที่ตรงนี้ยังไม่เจริญแต่ขณะนี้ถือว่า.wav
# --------------------------------------------------
# Processing: ครั้งนี้ขวัญยอมรับจ้ะจ้ะใช้ชื่อฝ่ายขู่ฮั้วสื่อจริง
# Selected speaker: VCTK_cv044 (ID: 43)
# Saving to: output_batch/tts_ครั้งนี้ขวัญยอมรับจ้ะจ้ะใช้ชื่อฝ่ายขู่ฮั้วสื่อจริง.wav
# --------------------------------------------------
# Processing: เพิ่มผลิตผลและเพิ่มรายได้ให้เกษตรกรสูงขึ้น
# Selected speaker: VCTK_cv030 (ID: 29)
# Saving to: output_batch/tts_เพิ่มผลิตผลและเพิ่มรายได้ให้เกษตรกรสูงขึ้น.wav
# --------------------------------------------------
# Processing: ที่กำลังทำงานอยู่ในครัวเธอหันไปพยักพเยิดกับสาวใช้แล้วว่าคุณหลานมาทีไรท่านก็แช่มชื่นทุกที
# Selected speaker: VCTK_cv010 (ID: 9)
# Saving to: output_batch/tts_ที่กำลังทำงานอยู่ในครัวเธอหันไปพยักพเยิดกับสาวใช้แล้วว่าคุณหลานมาทีไรท่านก็แช่มชื่นทุกที.wav
# --------------------------------------------------
# Processing: อย่าว่าแต่กินเลยมองยังไม่อยากมองศีลห้าข้อนี้ถือประพฤติมาตลอดแล้ว
# Selected speaker: VCTK_cv029 (ID: 28)
# Saving to: output_batch/tts_อย่าว่าแต่กินเลยมองยังไม่อยากมองศีลห้าข้อนี้ถือประพฤติมาตลอดแล้ว.wav
# --------------------------------------------------
# Processing: ให้อยู่ในรายชื่ออสังหาริมทรัพย์ที่มีอยู่มากมาย
# Selected speaker: VCTK_cv062 (ID: 61)
# Saving to: output_batch/tts_ให้อยู่ในรายชื่ออสังหาริมทรัพย์ที่มีอยู่มากมาย.wav
# --------------------------------------------------
# Processing: จนวันนี้เพราะไทยเราเองเป็นผู้ไปตั้งกลับให้มีขึ้น
# Selected speaker: VCTK_cv134 (ID: 133)
# Saving to: output_batch/tts_จนวันนี้เพราะไทยเราเองเป็นผู้ไปตั้งกลับให้มีขึ้น.wav
# --------------------------------------------------
# Processing: พูดพลางเดินนำหญิงสาวไปที่ม้านั่งยาว
# Selected speaker: VCTK_cv079 (ID: 78)
# Saving to: output_batch/tts_พูดพลางเดินนำหญิงสาวไปที่ม้านั่งยาว.wav
# --------------------------------------------------
# Processing: จะทำให้เงินสะพัดจากการแข่งขันประมาณสิบล้านบาท
# Selected speaker: VCTK_cv076 (ID: 75)
# Saving to: output_batch/tts_จะทำให้เงินสะพัดจากการแข่งขันประมาณสิบล้านบาท.wav
# --------------------------------------------------
# Processing: ที่มีกิจกรรมด้านการดัดแปรสภาพอากาศที่ขึ้นทะเบียนไว้รวมยี่สิบเจ็ดประเทศ
# Selected speaker: VCTK_cv101 (ID: 100)
# Saving to: output_batch/tts_ที่มีกิจกรรมด้านการดัดแปรสภาพอากาศที่ขึ้นทะเบียนไว้รวมยี่สิบเจ็ดประเทศ.wav
# --------------------------------------------------
# Processing: สารพิษซึ่งมีหรือเกิดขึ้นในสิ่งแวดล้อมรอบตัวเราที่เข้ามาปะปนหรือปนเปื้อนอาหาร
# Selected speaker: VCTK_cv076 (ID: 75)
# Saving to: output_batch/tts_สารพิษซึ่งมีหรือเกิดขึ้นในสิ่งแวดล้อมรอบตัวเราที่เข้ามาปะปนหรือปนเปื้อนอาหาร.wav
# --------------------------------------------------
# Processing: เช่นไม้รวกขนาดเล็กปักให้ชิดกับโคนต้นเอาเชือกผูกกิ่งติดกับหลักเพื่อกันลมโยก
# Selected speaker: VCTK_cv001 (ID: 0)
# Saving to: output_batch/tts_เช่นไม้รวกขนาดเล็กปักให้ชิดกับโคนต้นเอาเชือกผูกกิ่งติดกับหลักเพื่อกันลมโยก.wav
# --------------------------------------------------
# Processing: ยามนี้พิมลพัทธ์ไม่เหมือนหญิงสาววัยต้นผู้แจ่มใสมีชีวิตชีวาและเปี่ยมพลังคนเดิม
# Selected speaker: VCTK_cv089 (ID: 88)
# Saving to: output_batch/tts_ยามนี้พิมลพัทธ์ไม่เหมือนหญิงสาววัยต้นผู้แจ่มใสมีชีวิตชีวาและเปี่ยมพลังคนเดิม.wav
# --------------------------------------------------
# Processing: ดังนั้นหล่อนจึงลุกจากเก้าอี้มาคุกเข่าลงตรงหน้า
# Selected speaker: VCTK_cv028 (ID: 27)
# Saving to: output_batch/tts_ดังนั้นหล่อนจึงลุกจากเก้าอี้มาคุกเข่าลงตรงหน้า.wav
# --------------------------------------------------
# Processing: เมียซุกเบี้ยหกปึกไว้ใต้เบาะข้างโถฉัตร
# Selected speaker: VCTK_cv034 (ID: 33)
# Saving to: output_batch/tts_เมียซุกเบี้ยหกปึกไว้ใต้เบาะข้างโถฉัตร.wav
# --------------------------------------------------
# Processing: ชายที่นั่งท้ายใส่แว่นดำสวมเสื้อยืดดำลงจากอานหนังเดินมาถึงพลาง
# Selected speaker: VCTK_cv027 (ID: 26)
# Saving to: output_batch/tts_ชายที่นั่งท้ายใส่แว่นดำสวมเสื้อยืดดำลงจากอานหนังเดินมาถึงพลาง.wav
# --------------------------------------------------
# Processing: แม้จะรู้สึกผ่อนคลายในเหตุผลของเธอแต่ฉันก็ยังไม่ชอบใจอยู่ดี
# Selected speaker: VCTK_cv107 (ID: 106)
# Saving to: output_batch/tts_แม้จะรู้สึกผ่อนคลายในเหตุผลของเธอแต่ฉันก็ยังไม่ชอบใจอยู่ดี.wav
# --------------------------------------------------
# Processing: ดอกตูมใช้แกงส้มใบลวกจิ้มน้ำพริก
# Selected speaker: VCTK_cv058 (ID: 57)
# Saving to: output_batch/tts_ดอกตูมใช้แกงส้มใบลวกจิ้มน้ำพริก.wav
# --------------------------------------------------
# Processing: รอบตัวเงียบไปครู่ก่อนจะมีเสียงใสใสดังมาก่อนแต่ไกล
# Selected speaker: VCTK_cv130 (ID: 129)
# Saving to: output_batch/tts_รอบตัวเงียบไปครู่ก่อนจะมีเสียงใสใสดังมาก่อนแต่ไกล.wav
# --------------------------------------------------
# Processing: พิธีแต่งงานที่จัดขึ้นในบ้านเกิดของทั้งเจ้าบ่าวและเจ้าสาว
# Selected speaker: VCTK_cv130 (ID: 129)
# Saving to: output_batch/tts_พิธีแต่งงานที่จัดขึ้นในบ้านเกิดของทั้งเจ้าบ่าวและเจ้าสาว.wav
# --------------------------------------------------
# Processing: โดยพบหลักฐานการติดต่อและเข้ารับบริการจากคลินิกศัลยกรรมเสริมความงามและคลินิกสาวประเภทสองหลาย
# Selected speaker: VCTK_cv098 (ID: 97)
# Saving to: output_batch/tts_โดยพบหลักฐานการติดต่อและเข้ารับบริการจากคลินิกศัลยกรรมเสริมความงามและคลินิกสาวประเภทสองหลาย.wav
# --------------------------------------------------
# Processing: ซึ่งถูกไหม้จนเหลือแต่เสาตั้งโด่เด่ตรวจสอบในที่เกิดเหตุพบแกลลอนน้ำมันขนาดสี่ลิตร
# Selected speaker: VCTK_cv004 (ID: 3)
# Saving to: output_batch/tts_ซึ่งถูกไหม้จนเหลือแต่เสาตั้งโด่เด่ตรวจสอบในที่เกิดเหตุพบแกลลอนน้ำมันขนาดสี่ลิตร.wav
# --------------------------------------------------
# Processing: ทำให้การใช้ทรัพยากรธรรมชาติเป็นไปอย่างไม่เหมาะสมเกิดความเสื่อมโทรมในคุณภาพของชีวิตราษฎร
# Selected speaker: VCTK_cv091 (ID: 90)
# Saving to: output_batch/tts_ทำให้การใช้ทรัพยากรธรรมชาติเป็นไปอย่างไม่เหมาะสมเกิดความเสื่อมโทรมในคุณภาพของชีวิตราษฎร.wav
# --------------------------------------------------
# Processing: ทางนี้เลยเต้นกันยกใหญ่อย่างที่รู้กันเขาอยากได้ลูกสาวบึงน้ำใส
# Selected speaker: VCTK_cv096 (ID: 95)
# Saving to: output_batch/tts_ทางนี้เลยเต้นกันยกใหญ่อย่างที่รู้กันเขาอยากได้ลูกสาวบึงน้ำใส.wav
# --------------------------------------------------
# Processing: ไม่เหมือนในบัตรคริสต์มาสมันไม่ใช่กระท่อมแบบฝรั่งนี่คะนึกออกแล้วเหมือนในละครย้อนยุคน่ะเอง
# Selected speaker: VCTK_cv089 (ID: 88)
# Saving to: output_batch/tts_ไม่เหมือนในบัตรคริสต์มาสมันไม่ใช่กระท่อมแบบฝรั่งนี่คะนึกออกแล้วเหมือนในละครย้อนยุคน่ะเอง.wav
# --------------------------------------------------
# Processing: คำตอบที่ได้รับทำให้หญิงสาวสะดุ้งเฮือกขยับลุกขึ้นนั่งโดยเร็ว
# Selected speaker: VCTK_cv097 (ID: 96)
# Saving to: output_batch/tts_คำตอบที่ได้รับทำให้หญิงสาวสะดุ้งเฮือกขยับลุกขึ้นนั่งโดยเร็ว.wav
# --------------------------------------------------
# Processing: หากเธอก็ทำได้ด้วยการสนับสนุนเคี่ยวกรำอย่างหนักของพ่อแม่
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_หากเธอก็ทำได้ด้วยการสนับสนุนเคี่ยวกรำอย่างหนักของพ่อแม่.wav
# --------------------------------------------------
# Processing: ประเภทที่สองการหมักที่ใช้เกลือและมีข้าวหรือแป้งเป็นส่วนประกอบ
# Selected speaker: VCTK_cv026 (ID: 25)
# Saving to: output_batch/tts_ประเภทที่สองการหมักที่ใช้เกลือและมีข้าวหรือแป้งเป็นส่วนประกอบ.wav
# --------------------------------------------------
# Processing: เอเปรียบเทียบโป๊แบบเท่ดีซื้อเพราะความกว้าง
# Selected speaker: VCTK_cv048 (ID: 47)
# Saving to: output_batch/tts_เอเปรียบเทียบโป๊แบบเท่ดีซื้อเพราะความกว้าง.wav
# --------------------------------------------------
# Processing: ความแค้นเจ้าหน้าที่จึงแจ้งข้อกล่าวหาฆ่าผู้อื่นโดยเจตนา
# Selected speaker: VCTK_cv061 (ID: 60)
# Saving to: output_batch/tts_ความแค้นเจ้าหน้าที่จึงแจ้งข้อกล่าวหาฆ่าผู้อื่นโดยเจตนา.wav
# --------------------------------------------------
# Processing: แบกเบี่ยงผละเพลี่ยงแหงน
# Selected speaker: VCTK_cv109 (ID: 108)
# Saving to: output_batch/tts_แบกเบี่ยงผละเพลี่ยงแหงน.wav
# --------------------------------------------------
# Processing: ซึ่งหมายความว่าประชาชนในแถบนั้นร่ำรวยเพราะรายได้จากฝิ่นสูงมาก
# Selected speaker: VCTK_cv008 (ID: 7)
# Saving to: output_batch/tts_ซึ่งหมายความว่าประชาชนในแถบนั้นร่ำรวยเพราะรายได้จากฝิ่นสูงมาก.wav
# --------------------------------------------------
# Processing: เพราะหากปล่อยงูไว้อาจจะมีใครคนใดคนหนึ่งในครอบครัวถูกงูกัดมีพิษกัดเสียชีวิตได้
# Selected speaker: VCTK_cv106 (ID: 105)
# Saving to: output_batch/tts_เพราะหากปล่อยงูไว้อาจจะมีใครคนใดคนหนึ่งในครอบครัวถูกงูกัดมีพิษกัดเสียชีวิตได้.wav
# --------------------------------------------------
# Processing: มีผู้ติดฝิ่นน้อยมากเพราะผู้สูบผอมแห้งแรงน้อยและถูกประณามว่าเป็นขี้ยา
# Selected speaker: VCTK_cv099 (ID: 98)
# Saving to: output_batch/tts_มีผู้ติดฝิ่นน้อยมากเพราะผู้สูบผอมแห้งแรงน้อยและถูกประณามว่าเป็นขี้ยา.wav
# --------------------------------------------------
# Processing: ปักฟางเป็นลายดอกไม้ตรงหน้ากระโปรงเห็นแล้วอยากได้
# Selected speaker: VCTK_cv119 (ID: 118)
# Saving to: output_batch/tts_ปักฟางเป็นลายดอกไม้ตรงหน้ากระโปรงเห็นแล้วอยากได้.wav
# --------------------------------------------------
# Processing: ล้วนแสดงให้เห็นถึงลักษณะลวดลายผ้าไหมและผ้าซิ่นที่ใช้สืบต่อกันเรื่อยมา
# Selected speaker: VCTK_cv068 (ID: 67)
# Saving to: output_batch/tts_ล้วนแสดงให้เห็นถึงลักษณะลวดลายผ้าไหมและผ้าซิ่นที่ใช้สืบต่อกันเรื่อยมา.wav
# --------------------------------------------------
# Processing: แล้วผลุนผลันออกจากบ้านไป
# Selected speaker: VCTK_cv010 (ID: 9)
# Saving to: output_batch/tts_แล้วผลุนผลันออกจากบ้านไป.wav
# --------------------------------------------------
# Processing: พี่เลี้ยงนั่งตั้งพานบุปผาไว้ตรงหน้าหมอบประณตบทศรีแล้วว่าองค์นงนุชพระบุตรีร้อยมาลีมะลิลามาประทาน
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_พี่เลี้ยงนั่งตั้งพานบุปผาไว้ตรงหน้าหมอบประณตบทศรีแล้วว่าองค์นงนุชพระบุตรีร้อยมาลีมะลิลามาประทาน.wav
# --------------------------------------------------
# Processing: ตะโก้ลอดช่องขนมปลากริมไข่เต่าขนมใส่ไส้และขนมครกเป็นต้น
# Selected speaker: VCTK_cv073 (ID: 72)
# Saving to: output_batch/tts_ตะโก้ลอดช่องขนมปลากริมไข่เต่าขนมใส่ไส้และขนมครกเป็นต้น.wav
# --------------------------------------------------
# Processing: รอบคัดเลือกรอบสามนัดแรกวันอังคารที่แปดสิงหาคมนี้
# Selected speaker: VCTK_cv071 (ID: 70)
# Saving to: output_batch/tts_รอบคัดเลือกรอบสามนัดแรกวันอังคารที่แปดสิงหาคมนี้.wav
# --------------------------------------------------
# Processing: ง้านเรอะแต่ผมรู้ว่าคุณเล่นเก่งละ
# Selected speaker: VCTK_cv077 (ID: 76)
# Saving to: output_batch/tts_ง้านเรอะแต่ผมรู้ว่าคุณเล่นเก่งละ.wav
# --------------------------------------------------
# Processing: แต่ความคิดถึงก็ยังลอยเรื่อยเปื่อยต่อไปเมื่อมองภาพทารกบนชั้นวาง
# Selected speaker: VCTK_cv055 (ID: 54)
# Saving to: output_batch/tts_แต่ความคิดถึงก็ยังลอยเรื่อยเปื่อยต่อไปเมื่อมองภาพทารกบนชั้นวาง.wav
# --------------------------------------------------
# Processing: หญิงสาวทำท่าลังเลเขาปลอบว่า
# Selected speaker: VCTK_cv064 (ID: 63)
# Saving to: output_batch/tts_หญิงสาวทำท่าลังเลเขาปลอบว่า.wav
# --------------------------------------------------
# Processing: สิบห้าเครื่องใช้ในการรับแทงบอลเชื่อมโยงกับทางฮ่องกงไต้หวันและทางแถบเอเชีย
# Selected speaker: VCTK_cv126 (ID: 125)
# Saving to: output_batch/tts_สิบห้าเครื่องใช้ในการรับแทงบอลเชื่อมโยงกับทางฮ่องกงไต้หวันและทางแถบเอเชีย.wav
# --------------------------------------------------
# Processing: พร้อมทั้งภารกิจของการอบรมคณะศิษยานุศิษย์ท่านที่พักจำพรรษาด้วยกว่าสี่สิบรูป
# Selected speaker: VCTK_cv069 (ID: 68)
# Saving to: output_batch/tts_พร้อมทั้งภารกิจของการอบรมคณะศิษยานุศิษย์ท่านที่พักจำพรรษาด้วยกว่าสี่สิบรูป.wav
# --------------------------------------------------
# Processing: ส่วนไก่นั้นไม่ชอบน้ำว่ายน้ำไม่เป็นชอบเดินคุ้ยเขี่ยหาอาหารกินตามพื้นดิน
# Selected speaker: VCTK_cv054 (ID: 53)
# Saving to: output_batch/tts_ส่วนไก่นั้นไม่ชอบน้ำว่ายน้ำไม่เป็นชอบเดินคุ้ยเขี่ยหาอาหารกินตามพื้นดิน.wav
# --------------------------------------------------
# Processing: รัฐมนตรีว่าการคลังได้ยกตัวอย่างการเพิ่มขีดความสามารถในการแข่งขันเพื่อ
# Selected speaker: VCTK_cv096 (ID: 95)
# Saving to: output_batch/tts_รัฐมนตรีว่าการคลังได้ยกตัวอย่างการเพิ่มขีดความสามารถในการแข่งขันเพื่อ.wav
# --------------------------------------------------
# Processing: มีหลักการเดียวกันกับการกรองน้ำกะทิแบบเก่าเมื่อกรองได้เร็วหรือความ
# Selected speaker: VCTK_cv132 (ID: 131)
# Saving to: output_batch/tts_มีหลักการเดียวกันกับการกรองน้ำกะทิแบบเก่าเมื่อกรองได้เร็วหรือความ.wav
# --------------------------------------------------
# Processing: โดยให้วัตถุปักชำชื้นเพียงเล็กน้อยและปักพอตื้นเช่นเดียวกับการปักชำ
# Selected speaker: VCTK_cv123 (ID: 122)
# Saving to: output_batch/tts_โดยให้วัตถุปักชำชื้นเพียงเล็กน้อยและปักพอตื้นเช่นเดียวกับการปักชำ.wav
# --------------------------------------------------
# Processing: ตีหัวปล้นไกด์ในโรงแรมดัง
# Selected speaker: VCTK_cv108 (ID: 107)
# Saving to: output_batch/tts_ตีหัวปล้นไกด์ในโรงแรมดัง.wav
# --------------------------------------------------
# Processing: เดชะบุญฉันรอดมาได้คราวนี้แกทำแบบนี้ใส่ความเมียยังไม่พอ
# Selected speaker: VCTK_cv053 (ID: 52)
# Saving to: output_batch/tts_เดชะบุญฉันรอดมาได้คราวนี้แกทำแบบนี้ใส่ความเมียยังไม่พอ.wav
# --------------------------------------------------
# Processing: แต่ผู้ขับรถคันดังกล่าวถูกไฟคลอกเสียชีวิตอยู่ในรถ
# Selected speaker: VCTK_cv035 (ID: 34)
# Saving to: output_batch/tts_แต่ผู้ขับรถคันดังกล่าวถูกไฟคลอกเสียชีวิตอยู่ในรถ.wav
# --------------------------------------------------
# Processing: ตกสายของวันนั้นเธอก็ถูกพ่อแม่โทรศัพท์มาด่าแบบตัดพ่อตัดลูก
# Selected speaker: VCTK_cv026 (ID: 25)
# Saving to: output_batch/tts_ตกสายของวันนั้นเธอก็ถูกพ่อแม่โทรศัพท์มาด่าแบบตัดพ่อตัดลูก.wav
# --------------------------------------------------
# Processing: แสนรู้จริงสาระวารีชมเปาะอย่างจริงใจหากเพื่อนสาวกลับด่างึมมาตามสาย
# Selected speaker: VCTK_cv063 (ID: 62)
# Saving to: output_batch/tts_แสนรู้จริงสาระวารีชมเปาะอย่างจริงใจหากเพื่อนสาวกลับด่างึมมาตามสาย.wav
# --------------------------------------------------
# Processing: ซึ่งจะช่วยเพิ่มบรรยากาศของสวนให้เป็นสวนธรรมชาติได้เป็นอย่างมาก
# Selected speaker: VCTK_cv084 (ID: 83)
# Saving to: output_batch/tts_ซึ่งจะช่วยเพิ่มบรรยากาศของสวนให้เป็นสวนธรรมชาติได้เป็นอย่างมาก.wav
# --------------------------------------------------
# Processing: หล่อนกลืนน้ำลายลงคออย่างยากเย็นเมื่อนึกถึงสภาพตัวเองในหลายเดือนที่ผ่านมา
# Selected speaker: VCTK_cv013 (ID: 12)
# Saving to: output_batch/tts_หล่อนกลืนน้ำลายลงคออย่างยากเย็นเมื่อนึกถึงสภาพตัวเองในหลายเดือนที่ผ่านมา.wav
# --------------------------------------------------
# Processing: โดยรอบอ่างเล่นสีราวกับสายรุ้งต่ำลงมาคุณนายเจริญยกกระถางกุหลาบมาตั้งไว้โดยรอบ
# Selected speaker: VCTK_cv107 (ID: 106)
# Saving to: output_batch/tts_โดยรอบอ่างเล่นสีราวกับสายรุ้งต่ำลงมาคุณนายเจริญยกกระถางกุหลาบมาตั้งไว้โดยรอบ.wav
# --------------------------------------------------
# Processing: เขาหยิบตุ๊กตาหมาขนฟูสีขาวบริสุทธิ์ตัวใหญ่
# Selected speaker: VCTK_cv107 (ID: 106)
# Saving to: output_batch/tts_เขาหยิบตุ๊กตาหมาขนฟูสีขาวบริสุทธิ์ตัวใหญ่.wav
# --------------------------------------------------
# Processing: เชื่อว่าระบบควบคุมเงินทุนและระบบอัตราแลกเปลี่ยนของมาเลเซียจะไม่ล้มง่ายง่าย
# Selected speaker: VCTK_cv026 (ID: 25)
# Saving to: output_batch/tts_เชื่อว่าระบบควบคุมเงินทุนและระบบอัตราแลกเปลี่ยนของมาเลเซียจะไม่ล้มง่ายง่าย.wav
# --------------------------------------------------
# Processing: หญิงสาวเอื้อมมือไปแตะโทรศัพท์หากแล้วก็ยกไหล่แลบลิ้นและริมฝีปากนิดหนึ่ง
# Selected speaker: VCTK_cv087 (ID: 86)
# Saving to: output_batch/tts_หญิงสาวเอื้อมมือไปแตะโทรศัพท์หากแล้วก็ยกไหล่แลบลิ้นและริมฝีปากนิดหนึ่ง.wav
# --------------------------------------------------
# Processing: เพียงแค่เบื้องหน้าหล่อนจึงเห็นแววมุ่งมั่นที่ทำให้เขาชมเชยออกมาตรงตรงว่า
# Selected speaker: VCTK_cv092 (ID: 91)
# Saving to: output_batch/tts_เพียงแค่เบื้องหน้าหล่อนจึงเห็นแววมุ่งมั่นที่ทำให้เขาชมเชยออกมาตรงตรงว่า.wav
# --------------------------------------------------
# Processing: ทำให้มีโอกาสเกิดหลุมดำน้อยมากหรือถ้าเกิดก็จะเป็นขนาดเล็กมาก
# Selected speaker: VCTK_cv043 (ID: 42)
# Saving to: output_batch/tts_ทำให้มีโอกาสเกิดหลุมดำน้อยมากหรือถ้าเกิดก็จะเป็นขนาดเล็กมาก.wav
# --------------------------------------------------
# Processing: ฉันเองก็ถอนใจยาวเพราะรู้ตัวอยู่ว่ารอดพ้นจากความสงสัยของเขามาอย่างหวุดหวิด
# Selected speaker: VCTK_cv090 (ID: 89)
# ...
# --------------------------------------------------
# Processing: ก็รวบประดากล่องน้ำหอมลงถุงพลาสติกเลี่ยงออกไปอย่างมีมารยาท
# Selected speaker: VCTK_cv038 (ID: 37)
# Saving to: output_batch/tts_ก็รวบประดากล่องน้ำหอมลงถุงพลาสติกเลี่ยงออกไปอย่างมีมารยาท.wav
# --------------------------------------------------
# Processing: รู้บ้างเถอะไม่เหลือแบงก์หรือบ้านแล้วใครจะเจือครอบครัว
# Selected speaker: VCTK_cv134 (ID: 133)
# Saving to: output_batch/tts_รู้บ้างเถอะไม่เหลือแบงก์หรือบ้านแล้วใครจะเจือครอบครัว.wav
# --------------------------------------------------
# Processing: มีคำอธิบายที่แยบยลพอสำหรับการลบเลือนมิติของอำนาจในความสัมพันธ์ที่ไม่สู้จะสลับซับซ้อน
# Selected speaker: VCTK_cv036 (ID: 35)
# Saving to: output_batch/tts_มีคำอธิบายที่แยบยลพอสำหรับการลบเลือนมิติของอำนาจในความสัมพันธ์ที่ไม่สู้จะสลับซับซ้อน.wav
# --------------------------------------------------
# Processing: เมื่อประกาศให้ประชาชนแต่งกายตามแบบสากลจึงให้สวมรองเท้าและสวมหมวกด้วย
# Selected speaker: VCTK_cv093 (ID: 92)
# Saving to: output_batch/tts_เมื่อประกาศให้ประชาชนแต่งกายตามแบบสากลจึงให้สวมรองเท้าและสวมหมวกด้วย.wav
# --------------------------------------------------
# Processing: เลยปลุกระดมลูกน้องให้กระด้างกระเดื่องมันไม่ดี
# Selected speaker: VCTK_cv074 (ID: 73)
# Saving to: output_batch/tts_เลยปลุกระดมลูกน้องให้กระด้างกระเดื่องมันไม่ดี.wav
# --------------------------------------------------
# Processing: ที่รวยล้นฟ้าอย่างรวดเร็วกว่าในเมืองไทยท่ามกลางความเจ็บปวดของคนด้อยโอกาสทั่วไป
# Selected speaker: VCTK_cv108 (ID: 107)
# Saving to: output_batch/tts_ที่รวยล้นฟ้าอย่างรวดเร็วกว่าในเมืองไทยท่ามกลางความเจ็บปวดของคนด้อยโอกาสทั่วไป.wav
# --------------------------------------------------
# Processing: ดวงตาที่ดูเหมือนจะมีแววปราณีเมื่อครู่นี้จึงกลับเย่อหยิ่งชาเย็นเช่น
# Selected speaker: VCTK_cv083 (ID: 82)
# Saving to: output_batch/tts_ดวงตาที่ดูเหมือนจะมีแววปราณีเมื่อครู่นี้จึงกลับเย่อหยิ่งชาเย็นเช่น.wav
# --------------------------------------------------
# Processing: แต่ทุกวันนี้ต้องทำงานแบบตั้งรับรอวันพ่ายแพ้กว่าจะนำคนผิดมาลงโทษได้ยิ่งกว่าเข็นครกขึ้นภูเขา
# Selected speaker: VCTK_cv016 (ID: 15)
# Saving to: output_batch/tts_แต่ทุกวันนี้ต้องทำงานแบบตั้งรับรอวันพ่ายแพ้กว่าจะนำคนผิดมาลงโทษได้ยิ่งกว่าเข็นครกขึ้นภูเขา.wav
# --------------------------------------------------
# Processing: ฉันมาถึงก็สายมากแล้วค่ะเลยรีบแวะมาที่ทำงานก่อนฉันต้องขอประทานโทษ
# Selected speaker: VCTK_cv002 (ID: 1)
# Saving to: output_batch/tts_ฉันมาถึงก็สายมากแล้วค่ะเลยรีบแวะมาที่ทำงานก่อนฉันต้องขอประทานโทษ.wav
# --------------------------------------------------
# Processing: ปัญหาในเรื่องระหว่างความเป็นรัฐและชาติ
# Selected speaker: VCTK_cv086 (ID: 85)
# Saving to: output_batch/tts_ปัญหาในเรื่องระหว่างความเป็นรัฐและชาติ.wav
# --------------------------------------------------
# Processing: แต่ขอพระเจ้าพอดีมือเท้าหงิกงอกันไม่รู้จักช่วยตัวเองพระเจ้าก็งานหนักตาย
# Selected speaker: VCTK_cv058 (ID: 57)
# Saving to: output_batch/tts_แต่ขอพระเจ้าพอดีมือเท้าหงิกงอกันไม่รู้จักช่วยตัวเองพระเจ้าก็งานหนักตาย.wav
# --------------------------------------------------
# Processing: มาตราสี่ศักดิ์ศรีความเป็นมนุษย์สิทธิและเสรีภาพของบุคคลย่อมได้รับความคุ้มครอง
# Selected speaker: VCTK_cv034 (ID: 33)
# Saving to: output_batch/tts_มาตราสี่ศักดิ์ศรีความเป็นมนุษย์สิทธิและเสรีภาพของบุคคลย่อมได้รับความคุ้มครอง.wav
# --------------------------------------------------
# Processing: หน้าพาทย์ของละครชาตรีมีเพียงเก้าเพลง
# Selected speaker: VCTK_cv032 (ID: 31)
# Saving to: output_batch/tts_หน้าพาทย์ของละครชาตรีมีเพียงเก้าเพลง.wav
# --------------------------------------------------
# Processing: ดาวลับพายุผ่านแต่ดาวนั้นยังเรืองไกล
# Selected speaker: VCTK_cv050 (ID: 49)
# Saving to: output_batch/tts_ดาวลับพายุผ่านแต่ดาวนั้นยังเรืองไกล.wav
# --------------------------------------------------
# Processing: หน้าประตูบลังโกขึ้นโหม่งแต่บอลไปตรงตัวนายทวารเปลติโกซารับไว้
# Selected speaker: VCTK_cv036 (ID: 35)
# Saving to: output_batch/tts_หน้าประตูบลังโกขึ้นโหม่งแต่บอลไปตรงตัวนายทวารเปลติโกซารับไว้.wav
# --------------------------------------------------
# Processing: สีเหลืองได้มาจากขมิ้นชันสีส้มปนแดงจากดอกกรรณิการ์สีม่วงจากลูกหว้าเป็นต้น
# Selected speaker: VCTK_cv077 (ID: 76)
# Saving to: output_batch/tts_สีเหลืองได้มาจากขมิ้นชันสีส้มปนแดงจากดอกกรรณิการ์สีม่วงจากลูกหว้าเป็นต้น.wav
# --------------------------------------------------
# Processing: ช่วงสองสามวันนี้อากาศอบอุ่นขึ้นอย่างรวดเร็วอาจเป็น
# Selected speaker: VCTK_cv080 (ID: 79)
# Saving to: output_batch/tts_ช่วงสองสามวันนี้อากาศอบอุ่นขึ้นอย่างรวดเร็วอาจเป็น.wav
# --------------------------------------------------
# Processing: สนับเพลาเชิงงอนสายรัดพระองค์เพชรทรงพระสังวาลพระธำมรงค์ทรงพระมาลาเพชร
# Selected speaker: VCTK_cv111 (ID: 110)
# Saving to: output_batch/tts_สนับเพลาเชิงงอนสายรัดพระองค์เพชรทรงพระสังวาลพระธำมรงค์ทรงพระมาลาเพชร.wav
# --------------------------------------------------
# Processing: มุกโดนดุฟรีเป็นครั้งที่สองเอ๊ะหรือว่าที่สามนับไม่ถูกแล้ว
# Selected speaker: VCTK_cv019 (ID: 18)
# Saving to: output_batch/tts_มุกโดนดุฟรีเป็นครั้งที่สองเอ๊ะหรือว่าที่สามนับไม่ถูกแล้ว.wav
# --------------------------------------------------
# Processing: น้าคลั่งขู่ม็อบอย่าบ้าเพราะค่าเบี้ยเลี้ยงเหลือแค่เก้าดอก
# Selected speaker: VCTK_cv039 (ID: 38)
# Saving to: output_batch/tts_น้าคลั่งขู่ม็อบอย่าบ้าเพราะค่าเบี้ยเลี้ยงเหลือแค่เก้าดอก.wav
# --------------------------------------------------
# Processing: เจ้าของอธิบายให้มารดาเขาฟังด้วยสีหน้าจืดจืด
# Selected speaker: VCTK_cv040 (ID: 39)
# Saving to: output_batch/tts_เจ้าของอธิบายให้มารดาเขาฟังด้วยสีหน้าจืดจืด.wav
# --------------------------------------------------
# Processing: กระโจมหนังหลังน้อยตั้งอยู่โดดเดี่ยวห่างไกลจากกระโจมหลังอื่น
# Selected speaker: VCTK_cv018 (ID: 17)
# Saving to: output_batch/tts_กระโจมหนังหลังน้อยตั้งอยู่โดดเดี่ยวห่างไกลจากกระโจมหลังอื่น.wav
# --------------------------------------------------
# Processing: ทรัพยากรวัฒนธรรมเป็นของเปราะบางการจะซ่อมบูรณะหรือสงวนรักษานั้นต้องระวังไม่ให้เสียหายไปกว่าเดิม
# Selected speaker: VCTK_cv085 (ID: 84)
# Saving to: output_batch/tts_ทรัพยากรวัฒนธรรมเป็นของเปราะบางการจะซ่อมบูรณะหรือสงวนรักษานั้นต้องระวังไม่ให้เสียหายไปกว่าเดิม.wav
# --------------------------------------------------
# Processing: แล้วแหล่งทุนยังมีส่วนในการกำหนดประเด็นที่ควรทำวิจัยทั้งนี้
# Selected speaker: VCTK_cv009 (ID: 8)
# Saving to: output_batch/tts_แล้วแหล่งทุนยังมีส่วนในการกำหนดประเด็นที่ควรทำวิจัยทั้งนี้.wav
# --------------------------------------------------
# Processing: แล้วมุดประตูบานเล็กหน้าบ้านอาจารย์วิรุฬห์เข้าออกทุกเวลาเย็นย่ำ
# Selected speaker: VCTK_cv110 (ID: 109)
# Saving to: output_batch/tts_แล้วมุดประตูบานเล็กหน้าบ้านอาจารย์วิรุฬห์เข้าออกทุกเวลาเย็นย่ำ.wav
# --------------------------------------------------
# Processing: แนะสร้างโรงหมอใกล้บ้าน
# Selected speaker: VCTK_cv112 (ID: 111)
# Saving to: output_batch/tts_แนะสร้างโรงหมอใกล้บ้าน.wav
# --------------------------------------------------
# Processing: เมื่อแก๊งใต้ดินวางแผนบุกฉกตัวบรู๊คลีน
# Selected speaker: VCTK_cv124 (ID: 123)
# Saving to: output_batch/tts_เมื่อแก๊งใต้ดินวางแผนบุกฉกตัวบรู๊คลีน.wav
# --------------------------------------------------
# Processing: มีอาหารจีนทุกชนิดขนาดค้างคาวยังมีเคยกินมั้ยค้างคาวตุ๋นยาจีนบำรุงกำลังชั้นยอด
# Selected speaker: VCTK_cv076 (ID: 75)
# Saving to: output_batch/tts_มีอาหารจีนทุกชนิดขนาดค้างคาวยังมีเคยกินมั้ยค้างคาวตุ๋นยาจีนบำรุงกำลังชั้นยอด.wav
# --------------------------------------------------
# Processing: เกาะกลุ่มโผล่กลางทะเลลอยคอกว่านานสิบเอ็ดชั่วโมงท่ามกลางความมืดและทะเลโหด
# Selected speaker: VCTK_cv105 (ID: 104)
# Saving to: output_batch/tts_เกาะกลุ่มโผล่กลางทะเลลอยคอกว่านานสิบเอ็ดชั่วโมงท่ามกลางความมืดและทะเลโหด.wav
# --------------------------------------------------
# Processing: เช่นคำประเภทในน้ำมีปลาในนามีข้าวซึ่งเป็นคำคล้องจองที่ค่อนข้างเก่าแก่ที่สุดที่มีหลักฐานในศิลาจารึกพ่อขุนรามคำแหง
# Selected speaker: VCTK_cv096 (ID: 95)
# Saving to: output_batch/tts_เช่นคำประเภทในน้ำมีปลาในนามีข้าวซึ่งเป็นคำคล้องจองที่ค่อนข้างเก่าแก่ที่สุดที่มีหลักฐานในศิลาจารึกพ่อขุนรามคำแหง.wav
# --------------------------------------------------
# Processing: ก็ยืนยันจะเข้าร่วมการประชุมนัดนี้เพื่อให้แน่ใจว่าร่างกฎหมายนี้จะผ่านความเห็นชอบจากวุฒิสภา
# Selected speaker: VCTK_cv039 (ID: 38)
# Saving to: output_batch/tts_ก็ยืนยันจะเข้าร่วมการประชุมนัดนี้เพื่อให้แน่ใจว่าร่างกฎหมายนี้จะผ่านความเห็นชอบจากวุฒิสภา.wav
# --------------------------------------------------
# Processing: เพราะพ่อนำมาปลูกไว้ในรั้วที่ดินคนนอกที่เข้ามาเช่าห้องพักเท่านั้น
# Selected speaker: VCTK_cv106 (ID: 105)
# Saving to: output_batch/tts_เพราะพ่อนำมาปลูกไว้ในรั้วที่ดินคนนอกที่เข้ามาเช่าห้องพักเท่านั้น.wav
# --------------------------------------------------
# Processing: เพื่อนพี่ปุ๋มคนนั้นคนที่ผมลืมชื่อไปแล้วบอกทูตศักดาดู
# Selected speaker: VCTK_cv082 (ID: 81)
# Saving to: output_batch/tts_เพื่อนพี่ปุ๋มคนนั้นคนที่ผมลืมชื่อไปแล้วบอกทูตศักดาดู.wav
# --------------------------------------------------
# Processing: ความคิดสร้างสรรค์อย่างบรูณาการของประชาชน
# Selected speaker: VCTK_cv010 (ID: 9)
# Saving to: output_batch/tts_ความคิดสร้างสรรค์อย่างบรูณาการของประชาชน.wav
# --------------------------------------------------
# Processing: ให้ความเห็นกรณีถ้าถมที่ดินลงไปในทะเลนั้นกระทำไม่ได้
# Selected speaker: VCTK_cv128 (ID: 127)
# Saving to: output_batch/tts_ให้ความเห็นกรณีถ้าถมที่ดินลงไปในทะเลนั้นกระทำไม่ได้.wav
# --------------------------------------------------
# Processing: แม้ข้าราชการพ้อโดนสื่อไฮเทคแฉชื่อแต่มิขลาดหรือกลัว
# Selected speaker: VCTK_cv054 (ID: 53)
# Saving to: output_batch/tts_แม้ข้าราชการพ้อโดนสื่อไฮเทคแฉชื่อแต่มิขลาดหรือกลัว.wav
# --------------------------------------------------
# Processing: ในสมัยแรกเริ่มมนุษย์ได้อาศัยแหล่งธรรมชาติเป็นที่พักนอนชั่วคราวเช่นถ้ำและเพิงหิน
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_ในสมัยแรกเริ่มมนุษย์ได้อาศัยแหล่งธรรมชาติเป็นที่พักนอนชั่วคราวเช่นถ้ำและเพิงหิน.wav
# --------------------------------------------------
# Processing: โครงการอ่างเก็บน้ำห้วยเดียกอำเภอเมืองสกลนครจังหวัดสกลนครพื้นที่ได้รับประโยชน์ประมาณห้าไร่
# Selected speaker: VCTK_cv118 (ID: 117)
# Saving to: output_batch/tts_โครงการอ่างเก็บน้ำห้วยเดียกอำเภอเมืองสกลนครจังหวัดสกลนครพื้นที่ได้รับประโยชน์ประมาณห้าไร่.wav
# --------------------------------------------------
# Processing: ทำให้เธอดูสูงสง่าราวกับนางพญาดวงหน้าซึ่งล้อมด้วยผมดัดหยิกเป็นคลื่นอย่างสมัยใหม่เป็นดวงหน้า
# Selected speaker: VCTK_cv074 (ID: 73)
# Saving to: output_batch/tts_ทำให้เธอดูสูงสง่าราวกับนางพญาดวงหน้าซึ่งล้อมด้วยผมดัดหยิกเป็นคลื่นอย่างสมัยใหม่เป็นดวงหน้า.wav
# --------------------------------------------------
# Processing: ยังไงก็ต้องทนเรียนไม่มีสิทธิ์ดร็อปครั้งที่สองแล้วนะถ้าจะให้จบปีนี้ละก็
# Selected speaker: VCTK_cv103 (ID: 102)
# Saving to: output_batch/tts_ยังไงก็ต้องทนเรียนไม่มีสิทธิ์ดร็อปครั้งที่สองแล้วนะถ้าจะให้จบปีนี้ละก็.wav
# --------------------------------------------------
# Processing: นุ่งผ้าเหน็บหน้าหิ้วชายลอยชายและเข้าในสนวนประตูสนวนตะพานสนวนในรั้วไก่ในกะลาบาต
# Selected speaker: VCTK_cv014 (ID: 13)
# Saving to: output_batch/tts_นุ่งผ้าเหน็บหน้าหิ้วชายลอยชายและเข้าในสนวนประตูสนวนตะพานสนวนในรั้วไก่ในกะลาบาต.wav
# --------------------------------------------------
# Processing: คุยโม้อีกแล้วทำเป็นไอ้แป๋วแหววไปได้โธ่เอ๊ยกะอีสมบัติตอบข้อสอบเหมือนหนังสือเป๊ะแค่นี้มันจะหนักหนา
# Selected speaker: VCTK_cv044 (ID: 43)
# Saving to: output_batch/tts_คุยโม้อีกแล้วทำเป็นไอ้แป๋วแหววไปได้โธ่เอ๊ยกะอีสมบัติตอบข้อสอบเหมือนหนังสือเป๊ะแค่นี้มันจะหนักหนา.wav
# --------------------------------------------------
# Processing: ทำนองลำเต้ยหมายถึงเพลงสั้นสั้นที่ใช้ลำเกี้ยวกันและมีจังหวะคึกคักมีชีวิตชีวา
# Selected speaker: VCTK_cv125 (ID: 124)
# Saving to: output_batch/tts_ทำนองลำเต้ยหมายถึงเพลงสั้นสั้นที่ใช้ลำเกี้ยวกันและมีจังหวะคึกคักมีชีวิตชีวา.wav
# --------------------------------------------------
# Processing: โดยนักเรียนไทยที่สร้างชื่อคว้าเหรียญทองเคมีโอลิมปิกเหรียญแรกให้กับประเทศไทย
# Selected speaker: VCTK_cv059 (ID: 58)
# Saving to: output_batch/tts_โดยนักเรียนไทยที่สร้างชื่อคว้าเหรียญทองเคมีโอลิมปิกเหรียญแรกให้กับประเทศไทย.wav
# --------------------------------------------------
# Processing: กล้วยไม้ชนิดนี้มีชื่อเรียกอื่นอื่นได้แก่เอื้องกุหลาบกระเป๋าเปิดเอื้องกุหลาบป่าเอื้องกุหลาบพวงเอื้องด้ามข้าวและเอื้องปากเป็ดเยื้องกรมเพื่อประท้วงต่อป้ายสื่อโฆษณาเรื่องโฉ่ไข่ห้าฟอง
# Selected speaker: VCTK_cv065 (ID: 64)
# Saving to: output_batch/tts_กล้วยไม้ชนิดนี้มีชื่อเรียกอื่นอื่นได้แก่เอื้องกุหลาบกระเป๋าเปิดเอื้องกุหลาบป่าเอื้องกุหลาบพวงเอื้องด้ามข้าวและเอื้องปากเป็ดเยื้องกรมเพื่อประท้วงต่อป้ายสื่อโฆษณาเรื่องโฉ่ไข่ห้าฟอง.wav
# --------------------------------------------------
# Processing: ตามใจนะเขาว่าแล้วก็เอาจานใส่อาหารที่อุ่นจันทร์ทิ้งไว้ให้วางไว้ตรงหน้ากล่องใหญ่
# Selected speaker: VCTK_cv095 (ID: 94)
# Saving to: output_batch/tts_ตามใจนะเขาว่าแล้วก็เอาจานใส่อาหารที่อุ่นจันทร์ทิ้งไว้ให้วางไว้ตรงหน้ากล่องใหญ่.wav
# --------------------------------------------------
# Processing: ทั้งบ้านเงียบสงัดเสาวภาคย์เมียผมคงยังไม่กลับจากงานวันเกิดคุณวิทู
# Selected speaker: VCTK_cv009 (ID: 8)
# Saving to: output_batch/tts_ทั้งบ้านเงียบสงัดเสาวภาคย์เมียผมคงยังไม่กลับจากงานวันเกิดคุณวิทู.wav
# --------------------------------------------------
# Processing: หล่อนต้องการหนีไปให้พ้นไฝดำที่หางคิ้วขวาของเผด็จดิเรกกุล
# Selected speaker: VCTK_cv024 (ID: 23)
# Saving to: output_batch/tts_หล่อนต้องการหนีไปให้พ้นไฝดำที่หางคิ้วขวาของเผด็จดิเรกกุล.wav
# --------------------------------------------------
# Processing: อ๋อถ้าฉันเขยิบเข้าไปพ่อเจ้าประคุณจะได้เขยิบเข้ามาจำปาคิด
# Selected speaker: VCTK_cv096 (ID: 95)
# Saving to: output_batch/tts_อ๋อถ้าฉันเขยิบเข้าไปพ่อเจ้าประคุณจะได้เขยิบเข้ามาจำปาคิด.wav
# --------------------------------------------------
# Processing: ผมน่ะมีเมียมาแล้วสามลูกสองคุณเอ๊ยเชื่อผมเถอะ
# Selected speaker: VCTK_cv083 (ID: 82)
# Saving to: output_batch/tts_ผมน่ะมีเมียมาแล้วสามลูกสองคุณเอ๊ยเชื่อผมเถอะ.wav
# --------------------------------------------------
# Processing: เนื้อผลละเอียดสีเหลืองจัดรสหวานอมมันกลิ่นไม่ฉุนจัดตัวอย่างทุเรียนบางพันธุ์เช่น
# Selected speaker: VCTK_cv097 (ID: 96)
# Saving to: output_batch/tts_เนื้อผลละเอียดสีเหลืองจัดรสหวานอมมันกลิ่นไม่ฉุนจัดตัวอย่างทุเรียนบางพันธุ์เช่น.wav
# --------------------------------------------------
# Processing: นักข่าวสาวดึงแขนออกจากการเกาะกุมของเขาอย่างกระแทกกระทั้น
# Selected speaker: VCTK_cv078 (ID: 77)
# Saving to: output_batch/tts_นักข่าวสาวดึงแขนออกจากการเกาะกุมของเขาอย่างกระแทกกระทั้น.wav
# --------------------------------------------------
# Processing: พืชตระกูลถั่วและหญ้าบางชนิดส่วนวัสดุคลุมดินได้แก่เศษพืชเป็นต้น
# Selected speaker: VCTK_cv028 (ID: 27)
# Saving to: output_batch/tts_พืชตระกูลถั่วและหญ้าบางชนิดส่วนวัสดุคลุมดินได้แก่เศษพืชเป็นต้น.wav
# --------------------------------------------------
# Processing: การจับสมุนกลุ่มโจรที่มีค่าหัวกว่าห้าหมื่นบาทสอง
# Selected speaker: VCTK_cv012 (ID: 11)
# Saving to: output_batch/tts_การจับสมุนกลุ่มโจรที่มีค่าหัวกว่าห้าหมื่นบาทสอง.wav
# --------------------------------------------------
# Processing: ชายหนุ่มแปลกหน้าหัวเราะกว้างเข้าใจเจตนาของเขาเมื่อเอ่ยตอบ
# Selected speaker: VCTK_cv134 (ID: 133)
# Saving to: output_batch/tts_ชายหนุ่มแปลกหน้าหัวเราะกว้างเข้าใจเจตนาของเขาเมื่อเอ่ยตอบ.wav
# --------------------------------------------------
# Processing: เหล็กปลายแหลมใช้สำหรับเจาะไชงัดแงะมีสองชนิดคือ
# Selected speaker: VCTK_cv047 (ID: 46)
# Saving to: output_batch/tts_เหล็กปลายแหลมใช้สำหรับเจาะไชงัดแงะมีสองชนิดคือ.wav
# --------------------------------------------------
# Processing: คนตอบเป็นชายวัยหนุ่มแน่นสวมเสื้อยืดประเภทของแถมจากยาบำรุงกำลังบางชนิด
# Selected speaker: VCTK_cv012 (ID: 11)
# Saving to: output_batch/tts_คนตอบเป็นชายวัยหนุ่มแน่นสวมเสื้อยืดประเภทของแถมจากยาบำรุงกำลังบางชนิด.wav
# --------------------------------------------------
# Processing: เขาบ่นอย่างไม่ฟังเสียงต่อไปอีกว่า
# Selected speaker: VCTK_cv115 (ID: 114)
# Saving to: output_batch/tts_เขาบ่นอย่างไม่ฟังเสียงต่อไปอีกว่า.wav
# --------------------------------------------------
# Processing: แล้วยังให้ความหวังว่าอาจใช้การวัดความเข้มของแสงที่ได้เป็นดรรชนี
# Selected speaker: VCTK_cv007 (ID: 6)
# Saving to: output_batch/tts_แล้วยังให้ความหวังว่าอาจใช้การวัดความเข้มของแสงที่ได้เป็นดรรชนี.wav
# --------------------------------------------------
# Processing: และจะแก้ไขปัญหาต่างต่างได้เยอะตรงนี้ก็ต้องรับฟังไว้เหมือนกัน
# Selected speaker: VCTK_cv031 (ID: 30)
# Saving to: output_batch/tts_และจะแก้ไขปัญหาต่างต่างได้เยอะตรงนี้ก็ต้องรับฟังไว้เหมือนกัน.wav
# --------------------------------------------------
